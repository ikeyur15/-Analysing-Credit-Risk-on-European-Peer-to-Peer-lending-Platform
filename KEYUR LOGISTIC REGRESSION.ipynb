# %% [markdown]
# # Bondora Data Preprocessing
#
# In this project we will be doing credit risk modelling of peer to peer lending Bondora systems.Data for the study has been retrieved from a publicly available data set of a leading European P2P lending platform  ([**Bondora**](https://www.bondora.com/en/public-reports#dataset-file-format)).The retrieved data is a pool of both defaulted and non-defaulted loans from the time period between **1st March 2009** and **27th January 2020**. The data
# comprises of demographic and financial information of borrowers, and loan transactions.In P2P lending, loans are typically uncollateralized and lenders seek higher returns as a compensation for the financial risk they take. In addition, they need to make decisions under information asymmetry that works in favor of the borrowers. In order to make rational decisions, lenders want to minimize the risk of default of each lending decision, and realize the return that compensates for the risk.
#
# In this notebook we will preprocess the raw dataset and will create new preprocessed csv that can be used for building credit risk models.

# %%
# import 'Pandas' 
import pandas as pd 

# import 'Numpy' 
import numpy as np

# import subpackage of Matplotlib
import matplotlib.pyplot as plt

# import 'Seaborn' 
import seaborn as sns

# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# display all columns of the dataframe
pd.set_option('display.max_columns', 500)

# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.3f}'.format


# import various functions from statsmodel to perform linear regression
import statsmodels
import statsmodels.api as sm


# import train-test split 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px
pio.templates.default="plotly_dark"
from plotly.subplots import make_subplots
sns.set_style("darkgrid")
plt.style.use("fivethirtyeight")

# %%
#read the csv file 
df_main=pd.read_csv('Bondora_raw.csv',low_memory=True)

# %%
#check the shape/ length of each dimension of the df
df_main.shape
# Out:
# (134529, 112)

# %%
#check the total number of elements
df_main.size
# Out:
# 15067248

# %%
df_main.head()
# Out:
#   ReportAsOfEOD                                LoanId  LoanNumber  \
# 0    2020-01-27  F0660C80-83F3-4A97-8DA0-9C250112D6EC         659
# 1    2020-01-27  978BB85B-1C69-4D51-8447-9C240104A3A2         654
# 2    2020-01-27  EA44027E-7FA7-4BB2-846D-9C1F013C8A22         641
# 3    2020-01-27  CE67AD25-2951-4BEE-96BD-9C2700C61EF4         668
# 4    2020-01-27  9408BF8C-B159-4D6A-9D61-9C2400A986E3         652
#
#            ListedOnUTC     BiddingStartedOn  BidsPortfolioManager  BidsApi  \
# 0  2009-06-11 16:40:39  2009-06-11 16:40:39                     0        0
# 1  2009-06-10 15:48:57  2009-06-10 15:48:57                     0        0
# 2  2009-06-05 19:12:29  2009-06-05 19:12:29                     0        0
# 3  2009-06-13 12:01:20  2009-06-13 12:01:20                     0        0
# 4  2009-06-10 10:17:13  2009-06-10 10:17:13                     0        0
#
#    BidsManual  UserName  NewCreditCustomer LoanApplicationStartedDate  \
# 0     115.041      KARU               True        2009-06-11 16:40:39
# 1     140.606  koort681              False        2009-06-10 15:48:57
# 2     319.558       0ie               True        2009-06-05 19:12:29
# 3      57.520    Alyona               True        2009-06-13 12:01:20
# 4     319.558       Kai               True        2009-06-10 10:17:13
#
#      LoanDate ContractEndDate FirstPaymentDate MaturityDate_Original  \
# 0  2009-06-16      2010-07-06       2009-07-27            2010-06-25
# 1  2009-06-15      2009-07-07       2009-07-15            2009-07-15
# 2  2009-06-15             NaN       2009-07-27            2011-02-25
# 3  2009-06-15      2010-09-15       2009-07-15            2010-09-15
# 4  2009-06-14      2016-07-28       2009-07-27            2010-06-25
#
#   MaturityDate_Last  ApplicationSignedHour  ApplicationSignedWeekday  \
# 0        2010-06-25                     17                         5
# 1        2009-07-15                     20                         4
# 2        2014-05-13                     20                         6
# 3        2010-09-15                     12                         7
# 4        2010-06-25                     10                         4
#
#    VerificationType  LanguageCode  Age DateOfBirth  Gender Country  \
# 0             2.000             1   61  1947-11-26   1.000      EE
# 1             2.000             1   48  1960-11-05   1.000      EE
# 2             2.000             1   58  1950-11-13   1.000      EE
# 3             2.000             1   23  1986-03-29   1.000      EE
# 4             2.000             1   25  1983-09-30   1.000      EE
#
#    AppliedAmount  Amount  Interest  LoanDuration  MonthlyPayment    County  \
# 0        319.558 115.041    30.000            12             NaN     HARJU
# 1        191.735 140.606    25.000             1             NaN  IDA-VIRU
# 2        319.558 319.541    25.000            20             NaN     PÄRNU
# 3        127.823  57.520    45.000            15             NaN     HARJU
# 4        319.558 319.544    30.000            12             NaN     TARTU
#
#            City  UseOfLoan  Education  MaritalStatus NrOfDependants  \
# 0       TALLINN          7      3.000          1.000              0
# 1  KOHTLA-JARVE          7      5.000          4.000              0
# 2         PÄRNU          2      4.000          1.000              0
# 3      PALDISKI          0      2.000          3.000              1
# 4         TARTU          6      4.000          2.000              0
#
#    EmploymentStatus EmploymentDurationCurrentEmployer  \
# 0             3.000                        UpTo3Years
# 1             3.000                    MoreThan5Years
# 2             3.000                        UpTo4Years
# 3               NaN                        UpTo2Years
# 4             3.000                        UpTo2Years
#
#           EmploymentPosition   WorkExperience  OccupationArea  \
# 0          klienditeenindaja  MoreThan25Years           7.000
# 1  Õppealajuhataja lasteaias  MoreThan25Years          16.000
# 2                 teenindaja  MoreThan25Years           9.000
# 3               juhtmekoitja        2To5Years           1.000
# 4          klienditeenindaja       5To10Years           7.000
#
#    HomeOwnershipType  IncomeFromPrincipalEmployer  IncomeFromPension  \
# 0                NaN                     6000.000              0.000
# 1                NaN                     8300.000              0.000
# 2                NaN                     5000.000              0.000
# 3                NaN                    11000.000              0.000
# 4                NaN                     6800.000              0.000
#
#    IncomeFromFamilyAllowance  IncomeFromSocialWelfare  IncomeFromLeavePay  \
# 0                      0.000                    0.000               0.000
# 1                      0.000                    0.000               0.000
# 2                      0.000                    0.000               0.000
# 3                      0.000                    0.000               0.000
# 4                      0.000                    0.000               0.000
#
#    IncomeFromChildSupport  IncomeOther  IncomeTotal  ExistingLiabilities  \
# 0                   0.000     4500.000    10500.000                    0
# 1                   0.000     2500.000    10800.000                    0
# 2                   0.000     2000.000     7000.000                    0
# 3                   0.000      600.000    11600.000                    0
# 4                   0.000        0.000     6800.000                    0
#
#    LiabilitiesTotal  RefinanceLiabilities  DebtToIncome  FreeCash  \
# 0             0.000                     0         0.000     0.000
# 1             0.000                     0         0.000     0.000
# 2             0.000                     0         0.000     0.000
# 3             0.000                     0         0.000     0.000
# 4             0.000                     0         0.000     0.000
#
#    MonthlyPaymentDay  ActiveScheduleFirstPaymentReached  \
# 0                 25                               True
# 1                 15                               True
# 2                 25                               True
# 3                 15                               True
# 4                 25                               True
#
#    PlannedPrincipalTillDate  PlannedInterestTillDate LastPaymentOn  \
# 0                  1800.000                  319.080    2010-07-06
# 1                  2200.000                   45.830    2009-07-07
# 2                   319.541                  197.293    2012-10-01
# 3                   900.000                  293.100    2010-09-15
# 4                  5000.000                  833.810    2015-07-16
#
#    CurrentDebtDaysPrimary DebtOccuredOn  CurrentDebtDaysSecondary  \
# 0                     NaN           NaN                       NaN
# 1                     NaN           NaN                       NaN
# 2                2813.000    2012-05-14                  2935.000
# 3                     NaN           NaN                       NaN
# 4                     NaN           NaN                  3835.000
#
#   DebtOccuredOnForSecondary  ExpectedLoss  LossGivenDefault  ExpectedReturn  \
# 0                       NaN           NaN               NaN             NaN
# 1                       NaN           NaN               NaN             NaN
# 2                2012-01-13           NaN               NaN             NaN
# 3                       NaN           NaN               NaN             NaN
# 4                2009-07-27           NaN               NaN             NaN
#
#    ProbabilityOfDefault DefaultDate  PrincipalOverdueBySchedule  \
# 0                   NaN         NaN                         NaN
# 1                   NaN         NaN                         NaN
# 2                   NaN  2012-07-16                     116.350
# 3                   NaN         NaN                         NaN
# 4                   NaN  2009-09-28                         NaN
#
#    PlannedPrincipalPostDefault  PlannedInterestPostDefault    EAD1    EAD2  \
# 0                          NaN                         NaN     NaN     NaN
# 1                          NaN                         NaN     NaN     NaN
# 2                      236.970                      38.240 279.505 270.732
# 3                          NaN                         NaN     NaN     NaN
# 4                      247.760                      29.840 319.544 319.544
#
#    PrincipalRecovery  InterestRecovery  RecoveryStage     StageActiveSince  \
# 0                NaN               NaN            NaN                  NaN
# 1                NaN               NaN            NaN                  NaN
# 2            163.155            50.990            NaN  2016-03-03 00:00:00
# 3                NaN               NaN            NaN                  NaN
# 4            319.544           220.420            NaN                  NaN
#
#    ModelVersion Rating  EL_V0 Rating_V0  EL_V1 Rating_V1 Rating_V2  Status  \
# 0           NaN    NaN    NaN       NaN    NaN       NaN       NaN  Repaid
# 1           NaN    NaN    NaN       NaN    NaN       NaN       NaN  Repaid
# 2           NaN    NaN    NaN       NaN    NaN       NaN       NaN    Late
# 3           NaN    NaN    NaN       NaN    NaN       NaN       NaN  Repaid
# 4           NaN    NaN    NaN       NaN    NaN       NaN       NaN  Repaid
#
#    Restructured ActiveLateCategory WorseLateCategory CreditScoreEsMicroL  \
# 0         False                NaN            91-120                 NaN
# 1         False                NaN               NaN                 NaN
# 2          True               180+              180+                 NaN
# 3         False                NaN             31-60                 NaN
# 4         False                NaN              180+                 NaN
#
#   CreditScoreEsEquifaxRisk CreditScoreFiAsiakasTietoRiskGrade  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
#
#    CreditScoreEeMini  PrincipalPaymentsMade  InterestAndPenaltyPaymentsMade  \
# 0                NaN                115.041                          20.422
# 1                NaN                140.606                           2.023
# 2                NaN                203.191                          59.763
# 3                NaN                 57.520                          18.732
# 4                NaN                319.544                         220.420
#
#    PrincipalWriteOffs  InterestAndPenaltyWriteOffs  PrincipalBalance  \
# 0               0.000                        0.000             0.000
# 1               0.000                        0.000             0.000
# 2               0.000                        0.000           116.350
# 3               0.000                        0.000             0.000
# 4               0.000                        2.400             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsBefoleLoan  PreviousEarlyRepaymentsCountBeforeLoan  \
# 0                              0.000                                       0
# 1                              0.000                                       0
# 2                              0.000                                       0
# 3                              0.000                                       0
# 4                              0.000                                       0
#
#   GracePeriodStart GracePeriodEnd NextPaymentDate  NextPaymentNr  \
# 0              NaN            NaN             NaN            NaN
# 1              NaN            NaN             NaN            NaN
# 2              NaN            NaN             NaN            NaN
# 3              NaN            NaN             NaN            NaN
# 4              NaN            NaN             NaN            NaN
#
#    NrOfScheduledPayments ReScheduledOn  PrincipalDebtServicingCost  \
# 0                    NaN           NaN                       0.000
# 1                    NaN           NaN                       0.000
# 2                    NaN           NaN                       0.000
# 3                    NaN           NaN                       0.000
# 4                    NaN           NaN                       0.000
#
#    InterestAndPenaltyDebtServicingCost ActiveLateLastPaymentCategory
# 0                                0.000                           NaN
# 1                                0.000                           NaN
# 2                                0.000                          180+
# 3                                0.000                           NaN
# 4                                0.000                          180+

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# | Feature                                | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |----------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | ActiveLateCategory                     | When a loan is in Principal Debt then it will be categorized by Principal Debt days                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | ActiveLateLastPaymentCategory          | Shows how many days has passed since last payment and categorised if it is overdue                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | ActiveScheduleFirstPaymentReached      | Whether the first payment date has been reached according to the active schedule                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | Age                                    | The age of the borrower when signing the loan application                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | Amount                                 | Amount the borrower received on the Primary Market. This is the principal balance of your purchase from Secondary Market                                                                                                                                                                                                                                                                                                                                                                                            |
# | AmountOfPreviousLoansBeforeLoan        | Value of previous loans                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | AppliedAmount                          | The amount borrower applied for originally                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | AuctionBidNumber                       | Unique bid number which is accompanied by Auction number                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | AuctionId                              | A unique number given to all auctions                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | AuctionName                            | Name of the Auction, in newer loans it is defined by the purpose of the loan                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | AuctionNumber                          | Unique auction number which is accompanied by Bid number                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | BidPrincipal                           | On Primary Market BidPrincipal is the amount you made your bid on. On Secondary Market BidPrincipal is the purchase price                                                                                                                                                                                                                                                                                                                                                                                           |
# | BidsApi                                | The amount of investment offers made via Api                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | BidsManual                             | The amount of investment offers made manually                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | BidsPortfolioManager                   | The amount of investment offers made by Portfolio Managers                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | BoughtFromResale_Date                  | The time when the investment was purchased from the Secondary Market                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | City                                   | City of the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | ContractEndDate                        | The date when the loan contract ended                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | Country                                | Residency of the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | County                                 | County of the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | CreditScoreEeMini                      | 1000 No previous payments problems 900 Payments problems finished 24-36 months ago 800 Payments problems finished 12-24 months ago 700 Payments problems finished 6-12 months ago 600 Payment problems finished < 6 months ago 500 Active payment problems                                                                                                                                                                                                                                                          |
# | CreditScoreEsEquifaxRisk               | Generic score for the loan applicants that do not have active past due operations in ASNEF; a measure of the probability of default one year ahead; the score is given on a 6-grade scale: AAA (“Very low”), AA (“Low”), A (“Average”), B (“Average High”), C (“High”), D (“Very High”).                                                                                                                                                                                                                            |
# | CreditScoreEsMicroL                    | A score that is specifically designed for risk classifying subprime borrowers (defined by Equifax as borrowers that do not have access to bank loans); a measure of the probability of default one month ahead; the score is given on a 10-grade scale, from the best score to the worst: M1, M2, M3, M4, M5, M6, M7, M8, M9, M10.                                                                                                                                                                                  |
# | CreditScoreFiAsiakasTietoRiskGrade     | Credit Scoring model for Finnish Asiakastieto RL1 Very low risk 01-20 RL2 Low risk 21-40 RL3 Average risk 41-60 RL4 Big risk 61-80 RL5 Huge risk 81-100                                                                                                                                                                                                                                                                                                                                                             |
# | CurrentDebtDaysPrimary                 | How long the loan has been in Principal Debt                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | CurrentDebtDaysSecondary               | How long the loan has been in Interest Debt                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | DateOfBirth                            | The date of the borrower's birth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | DebtOccuredOn                          | The date when Principal Debt occurred                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | DebtOccuredOnForSecondary              | The date when Interest Debt occurred                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | DebtToIncome                           | Ratio of borrower's monthly gross income that goes toward paying loans                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | DefaultDate                            | The date when loan went into defaulted state and collection process was started                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | DesiredDiscountRate                    | Investment being sold at a discount or premium                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | EAD1                                   | Exposure at default, outstanding principal at default                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | EAD2                                   | Exposure at default, loan amount less all payments prior to default                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | Education                              | 1 Primary education 2 Basic education 3 Vocational education 4 Secondary education 5 Higher education                                                                                                                                                                                                                                                                                                                                                                                                               |
# | EL_V0                                  | Expected loss calculated by the specified version of Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | EL_V1                                  | Expected loss calculated by the specified version of Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | EL_V2                                  | Expected loss calculated by the specified version of Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | EmploymentDurationCurrentEmployer      | Employment time with the current employer                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | EmploymentPosition                     | Employment position with the current employer                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | EmploymentStatus                       | 1 Unemployed 2 Partially employed 3 Fully employed 4 Self-employed 5 Entrepreneur 6 Retiree                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | ExistingLiabilities                    | Borrower's number of existing liabilities                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | ExpectedLoss                           | Expected Loss calculated by the current Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | ExpectedReturn                         | Expected Return calculated by the current Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | FirstPaymentDate                       | First payment date according to initial loan schedule                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | FreeCash                               | Discretionary income after monthly liabilities                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | Gender                                 | 0 Male 1 Woman 2 Undefined                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | GracePeriodEnd                         | Date of the end of Grace period                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | GracePeriodStart                       | Date of the beginning of Grace period                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | HomeOwnershipType                      | 0 Homeless 1 Owner 2 Living with parents 3 Tenant, pre-furnished property 4 Tenant, unfurnished property 5 Council house 6 Joint tenant 7 Joint ownership 8 Mortgage 9 Owner with encumbrance 10 Other                                                                                                                                                                                                                                                                                                              |
# | IncomeFromChildSupport                 | Borrower's income from alimony payments                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | IncomeFromFamilyAllowance              | Borrower's income from child support                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | IncomeFromLeavePay                     | Borrower's income from paternity leave                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | IncomeFromPension                      | Borrower's income from pension                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | IncomeFromPrincipalEmployer            | Borrower's income from its employer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | IncomeFromSocialWelfare                | Borrower's income from social support                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | IncomeOther                            | Borrower's income from other sources                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | IncomeTotal                            | Borrower's total income                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | Interest                               | Maximum interest rate accepted in the loan application                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | InterestAndPenaltyBalance              | Unpaid interest and penalties                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | InterestAndPenaltyDebtServicingCost    | Service cost related to the recovery of the debt based on the interest and penalties of the investment                                                                                                                                                                                                                                                                                                                                                                                                              |
# | InterestAndPenaltyPaymentsMade         | Note owner received loan transfers earned interest, penalties total amount                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | InterestAndPenaltyWriteOffs            | Interest that was written off on the investment                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | InterestLateAmount                     | Interest debt amount                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | InterestRecovery                       | Interest recovered due to collection process from in debt loans                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | LanguageCode                           | 1 Estonian 2 English 3 Russian 4 Finnish 5 German 6 Spanish 9 Slovakian                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | LastPaymentOn                          | The date of the current last payment received from the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | LiabilitiesTotal                       | Total monthly liabilities                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | ListedOnUTC                            | Date when the loan application appeared on Primary Market                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | LoanDate                               | Date when the loan was issued                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | LoanDuration                           | Current loan duration in months                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | LoanId                                 | A unique ID given to all loan applications                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | LoanNumber                             | A unique number given to all loan applications                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | LoanStatusActiveFrom                   | How long the current status has been active                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | LossGivenDefault                       | Gives the percentage of outstanding exposure at the time of default that an investor is likely to lose if a loan actually defaults. This means the proportion of funds lost for the investor after all expected recovery and accounting for the time value of the money recovered. In general, LGD parameter is intended to be estimated based on the historical recoveries. However, in new markets where limited experience does not allow us more precise loss given default estimates, a LGD of 90% is assumed. |
# | MaritalStatus                          | 1 Married 2 Cohabitant 3 Single 4 Divorced 5 Widow                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | MaturityDate_Last                      | Loan maturity date according to the current payment schedule                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | MaturityDate_Original                  | Loan maturity date according to the original loan schedule                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | ModelVersion                           | The version of the Rating model used for issuing the Bondora Rating                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | MonthlyPayment                         | Estimated amount the borrower has to pay every month                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | MonthlyPaymentDay                      | The day of the month the loan payments are scheduled for The actual date is adjusted for weekends and bank holidays (e.g. if 10th is Sunday then the payment will be made on the 11th in that month)                                                                                                                                                                                                                                                                                                                |
# | NewCreditCustomer                      | Did the customer have prior credit history in Bondora 0 Customer had at least 3 months of credit history in Bondora 1 No prior credit history in Bondora                                                                                                                                                                                                                                                                                                                                                            |
# | NextPaymentDate                        | According to schedule the next date for borrower to make their payment                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | NextPaymentNr                          | According to schedule the number of the next payment                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | NextPaymentSum                         | According to schedule the amount of the next payment                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | NoOfPreviousLoansBeforeLoan            | Number of previous loans                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | note_id                                | A unique ID given to the investments                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | NoteLoanLateChargesPaid                | The amount of late charges the note has received                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | NoteLoanTransfersInterestAmount        | The amount of interest the note has received                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | NoteLoanTransfersMainAmount            | The amount of principal the note has received                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | NrOfDependants                         | Number of children or other dependants                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | NrOfScheduledPayments                  | According to schedule the count of scheduled payments                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | OccupationArea                         | 1 Other 2 Mining 3 Processing 4 Energy 5 Utilities 6 Construction 7 Retail and wholesale 8 Transport and warehousing 9 Hospitality and catering 10 Info and telecom 11 Finance and insurance 12 Real-estate 13 Research 14 Administrative 15 Civil service & military 16 Education 17 Healthcare and social help 18 Art and entertainment 19 Agriculture, forestry and fishing                                                                                                                                      |
# | OnSaleSince                            | Time when the investment was added to Secondary Market                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | PenaltyLateAmount                      | Late charges debt amount                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | PlannedInterestPostDefault             | The amount of interest that was planned to be received after the default occurred                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | PlannedInterestTillDate                | According to active schedule the amount of interest the investment should have received                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | PlannedPrincipalPostDefault            | The amount of principal that was planned to be received after the default occurred                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | PlannedPrincipalTillDate               | According to active schedule the amount of principal the investment should have received                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | PreviousEarlyRepaymentsBeforeLoan      | How much was the early repayment amount before the loan                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | PreviousEarlyRepaymentsCountBeforeLoan | How many times the borrower had repaid early                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | PreviousRepaymentsBeforeLoan           | How much the borrower had repaid before the loan                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | PrincipalBalance                       | Principal that still needs to be paid by the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | PrincipalDebtServicingCost             | Service cost related to the recovery of the debt based on the principal of the investment                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | PrincipalLateAmount                    | Principal debt amount                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | PrincipalOverdueBySchedule             | According to the current schedule, principal that is overdue                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | PrincipalPaymentsMade                  | Note owner received loan transfers principal amount                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | PrincipalRecovery                      | Principal recovered due to collection process from in debt loans                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | PrincipalWriteOffs                     | Principal that was written off on the investment                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | ProbabilityOfDefault                   | Probability of Default, refers to a loan’s probability of default within one year horizon.                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | PurchasePrice                          | Investment amount or secondary market purchase price                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | Rating                                 | Bondora Rating issued by the Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | Rating_V0                              | Bondora Rating issued by version 0 of the Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | Rating_V1                              | Bondora Rating issued by version 1 of the Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | Rating_V2                              | Bondora Rating issued by version 2 of the Rating model                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | RecoveryStage                          | Current stage according to the recovery model 1 Collection 2 Recovery 3 Write Off                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | RefinanceLiabilities                   | The total amount of liabilities after refinancing                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | ReScheduledOn                          | The date when the a new schedule was assigned to the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | Restructured                           | The original maturity date of the loan has been increased by more than 60 days                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | SoldInResale_Date                      | The date when the investment was sold on Secondary market                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | SoldInResale_Price                     | The price of the investment that was sold on Secondary market                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | SoldInResale_Principal                 | The principal remaining of the investment that was sold on Secondary market                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | StageActiveSince                       | How long the current recovery stage has been active                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | Status                                 | The current status of the loan application                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | UseOfLoan                              | 0 Loan consolidation 1 Real estate 2 Home improvement 3 Business 4 Education 5 Travel 6 Vehicle 7 Other 8 Health 101 Working capital financing 102 Purchase of machinery equipment 103 Renovation of real estate 104 Accounts receivable financing 105 Acquisition of means of transport 106 Construction finance 107 Acquisition of stocks 108 Acquisition of real estate 109 Guaranteeing obligation 110 Other business All codes in format 1XX are for business loans that are not supported since October 2012  |
# | UserName                               | The user name generated by the system for the borrower                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | VerificationType                       | Method used for loan application data verification 0 Not set 1 Income unverified 2 Income unverified, cross-referenced by phone 3 Income verified 4 Income and expenses verified                                                                                                                                                                                                                                                                                                                                    |
# | WorkExperience                         | Borrower's overall work experience in years                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | WorseLateCategory                      | Displays the last longest period of days when the loan was in Principal Debt                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | XIRR                                   | XIRR (extended internal rate of return) is a methodology to calculate the net return using the loan issued date and amount, loan repayment dates and amounts and the principal balance according to the original repayment date. All overdue principal payments are written off immediately. No provisions for future losses are made & only received (not accrued or scheduled) interest payments are taken into account.                                                                                          |

# %% [markdown]
# # Target variable

# %%
# "STATUS" IS OUR TARGET VARIABLE
t_v = df_main['Status']
t_v
# Out:
# 0         Repaid
# 1         Repaid
# 2           Late
# 3         Repaid
# 4         Repaid
#            ...
# 134524    Repaid
# 134525    Repaid
# 134526      Late
# 134527    Repaid
# 134528      Late
# Name: Status, Length: 134529, dtype: object

# %% [markdown]
# # Percentage of Missing Values

# %%
# To show all the rows of pandas dataframe
# df.isnull().sum()*100/len(df)

total_missing_val=df_main.isnull().sum()*100/len(df_main)

def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

print_full(total_missing_val)

# df.isnull().mean().tolist()
# Out:
# ReportAsOfEOD                             0.000
# LoanId                                    0.000
# LoanNumber                                0.000
# ListedOnUTC                               0.000
# BiddingStartedOn                          0.000
# BidsPortfolioManager                      0.000
# BidsApi                                   0.000
# BidsManual                                0.000
# UserName                                  0.000
# NewCreditCustomer                         0.000
# LoanApplicationStartedDate                0.000
# LoanDate                                  0.000
# ContractEndDate                          56.156
# FirstPaymentDate                          0.000
# MaturityDate_Original                     0.000
# MaturityDate_Last                         0.000
# ApplicationSignedHour                     0.000
# ApplicationSignedWeekday                  0.000
# VerificationType                          0.033
# LanguageCode                              0.000
# Age                                       0.000
# DateOfBirth                               0.000
# Gender                                    0.033
# Country                                   0.000
# AppliedAmount                             0.000
# Amount                                    0.000
# Interest                                  0.000
# LoanDuration                              0.000
# MonthlyPayment                            4.969
# County                                   27.384
# City                                      7.280
# UseOfLoan                                 0.000
# Education                                 0.033
# MaritalStatus                             0.033
# NrOfDependants                           73.537
# EmploymentStatus                          0.146
# EmploymentDurationCurrentEmployer         0.651
# EmploymentPosition                       73.173
# WorkExperience                           72.852
# OccupationArea                            0.064
# HomeOwnershipType                         1.228
# IncomeFromPrincipalEmployer               0.000
# IncomeFromPension                         0.000
# IncomeFromFamilyAllowance                 0.000
# IncomeFromSocialWelfare                   0.000
# IncomeFromLeavePay                        0.000
# IncomeFromChildSupport                    0.000
# IncomeOther                               0.000
# IncomeTotal                               0.000
# ExistingLiabilities                       0.000
# LiabilitiesTotal                          0.000
# RefinanceLiabilities                      0.000
# DebtToIncome                              0.033
# FreeCash                                  0.033
# MonthlyPaymentDay                         0.000
# ActiveScheduleFirstPaymentReached         0.000
# PlannedPrincipalTillDate                 59.519
# PlannedInterestTillDate                   2.930
# LastPaymentOn                             7.085
# CurrentDebtDaysPrimary                   63.935
# DebtOccuredOn                            63.935
# CurrentDebtDaysSecondary                 61.161
# DebtOccuredOnForSecondary                61.161
# ExpectedLoss                              1.959
# LossGivenDefault                          1.959
# ExpectedReturn                            1.959
# ProbabilityOfDefault                      1.959
# DefaultDate                              68.100
# PrincipalOverdueBySchedule               11.029
# PlannedPrincipalPostDefault              68.100
# PlannedInterestPostDefault               68.100
# EAD1                                     68.100
# EAD2                                     68.100
# PrincipalRecovery                        68.100
# InterestRecovery                         68.100
# RecoveryStage                            42.584
# StageActiveSince                         39.824
# ModelVersion                              1.959
# Rating                                    2.029
# EL_V0                                    96.604
# Rating_V0                                96.604
# EL_V1                                    90.395
# Rating_V1                                90.395
# Rating_V2                                81.310
# Status                                    0.000
# Restructured                              0.000
# ActiveLateCategory                       63.935
# WorseLateCategory                        33.789
# CreditScoreEsMicroL                      21.983
# CreditScoreEsEquifaxRisk                 90.917
# CreditScoreFiAsiakasTietoRiskGrade       75.828
# CreditScoreEeMini                        46.687
# PrincipalPaymentsMade                     0.000
# InterestAndPenaltyPaymentsMade            0.000
# PrincipalWriteOffs                       56.047
# InterestAndPenaltyWriteOffs              56.047
# PrincipalBalance                          0.000
# InterestAndPenaltyBalance                 0.000
# NoOfPreviousLoansBeforeLoan               0.000
# AmountOfPreviousLoansBeforeLoan           0.000
# PreviousRepaymentsBeforeLoan             32.083
# PreviousEarlyRepaymentsBefoleLoan        56.867
# PreviousEarlyRepaymentsCountBeforeLoan    0.000
# GracePeriodStart                         86.034
# GracePeriodEnd                           86.034
# NextPaymentDate                          51.205
# NextPaymentNr                            27.311
# NrOfScheduledPayments                    27.311
# ReScheduledOn                            70.027
# PrincipalDebtServicingCost               56.047
# InterestAndPenaltyDebtServicingCost      56.047
# ActiveLateLastPaymentCategory            61.161
# dtype: float64

# %% [markdown]
# # Removing all the features which have more than 40% missing values

# %%
# removing the columns having more than 40% missing values
df_val_null_less_then_40 = df_main.columns[total_missing_val <40]
df_val_null_less_then_40

# df[df.columns[df.isnull().mean() < 0.4]]
# Out:
# Index(['ReportAsOfEOD', 'LoanId', 'LoanNumber', 'ListedOnUTC',
#        'BiddingStartedOn', 'BidsPortfolioManager', 'BidsApi', 'BidsManual',
#        'UserName', 'NewCreditCustomer', 'LoanApplicationStartedDate',
#        'LoanDate', 'FirstPaymentDate', 'MaturityDate_Original',
#        'MaturityDate_Last', 'ApplicationSignedHour',
#        'ApplicationSignedWeekday', 'VerificationType', 'LanguageCode', 'Age',
#        'DateOfBirth', 'Gender', 'Country', 'AppliedAmount', 'Amount',
#        'Interest', 'LoanDuration', 'MonthlyPayment', 'County', 'City',
#        'UseOfLoan', 'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'IncomeFromPrincipalEmployer', 'IncomeFromPension',
#        'IncomeFromFamilyAllowance', 'IncomeFromSocialWelfare',
#        'IncomeFromLeavePay', 'IncomeFromChildSupport', 'IncomeOther',
#        'IncomeTotal', 'ExistingLiabilities', 'LiabilitiesTotal',
#        'RefinanceLiabilities', 'DebtToIncome', 'FreeCash', 'MonthlyPaymentDay',
#        'ActiveScheduleFirstPaymentReached', 'PlannedInterestTillDate',
#        'LastPaymentOn', 'ExpectedLoss', 'LossGivenDefault', 'ExpectedReturn',
#        'ProbabilityOfDefault', 'PrincipalOverdueBySchedule',
#        'StageActiveSince', 'ModelVersion', 'Rating', 'Status', 'Restructured',
#        'WorseLateCategory', 'CreditScoreEsMicroL', 'PrincipalPaymentsMade',
#        'InterestAndPenaltyPaymentsMade', 'PrincipalBalance',
#        'InterestAndPenaltyBalance', 'NoOfPreviousLoansBeforeLoan',
#        'AmountOfPreviousLoansBeforeLoan', 'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan', 'NextPaymentNr',
#        'NrOfScheduledPayments'],
#       dtype='object')

# %%
# print missing values columns 

miss_col=['ContractEndDate', 'NrOfDependants', 'EmploymentPosition',
       'WorkExperience', 'PlannedPrincipalTillDate', 'CurrentDebtDaysPrimary',
       'DebtOccuredOn', 'CurrentDebtDaysSecondary',
       'DebtOccuredOnForSecondary',
       'PlannedPrincipalPostDefault', 'PlannedInterestPostDefault', 'EAD1',
       'EAD2', 'PrincipalRecovery', 'InterestRecovery', 'RecoveryStage',
       'EL_V0', 'Rating_V0', 'EL_V1', 'Rating_V1', 'Rating_V2',
       'ActiveLateCategory', 'CreditScoreEsEquifaxRisk',
       'CreditScoreFiAsiakasTietoRiskGrade', 'CreditScoreEeMini',
       'PrincipalWriteOffs', 'InterestAndPenaltyWriteOffs',
       'PreviousEarlyRepaymentsBefoleLoan', 'GracePeriodStart',
       'GracePeriodEnd', 'NextPaymentDate', 'ReScheduledOn',
       'PrincipalDebtServicingCost', 'InterestAndPenaltyDebtServicingCost',
       'ActiveLateLastPaymentCategory']

# %%
# drop missing  values columns )
df_drop_m_val =df_main.drop(miss_col,axis=1)
df_drop_m_val.shape
# Out:
# (134529, 77)

# %% [markdown]
# Apart from missing value features there are some features which will have no role in default prediction like 'ReportAsOfEOD', 'LoanId', 'LoanNumber', 'ListedOnUTC', 'DateOfBirth' (**because age is already present**), 'BiddingStartedOn','UserName','NextPaymentNr','NrOfScheduledPayments','IncomeFromPrincipalEmployer', 'IncomeFromPension',
# 'IncomeFromFamilyAllowance', 'IncomeFromSocialWelfare','IncomeFromLeavePay', 'IncomeFromChildSupport', 'IncomeOther' (**As Total income is already present which is total of all these income**), 'LoanApplicationStartedDate','ApplicationSignedHour',
#        'ApplicationSignedWeekday','ActiveScheduleFirstPaymentReached', 'PlannedInterestTillDate',
#        'LastPaymentOn', 'ExpectedLoss', 'LossGivenDefault', 'ExpectedReturn',
#        'ProbabilityOfDefault', 'PrincipalOverdueBySchedule',
#        'StageActiveSince', 'ModelVersion','WorseLateCategory'

# %%
#we have to remove these columns.
cols_del = ['ReportAsOfEOD', 'LoanId', 'LoanNumber', 'ListedOnUTC', 'DateOfBirth',
       'BiddingStartedOn','UserName','NextPaymentNr',
       'NrOfScheduledPayments','IncomeFromPrincipalEmployer', 'IncomeFromPension',
       'IncomeFromFamilyAllowance', 'IncomeFromSocialWelfare',
       'IncomeFromLeavePay', 'IncomeFromChildSupport', 'IncomeOther','LoanApplicationStartedDate','ApplicationSignedHour',
       'ApplicationSignedWeekday','ActiveScheduleFirstPaymentReached', 'PlannedInterestTillDate',
       'ExpectedLoss', 'LossGivenDefault', 'ExpectedReturn',
       'ProbabilityOfDefault', 'PrincipalOverdueBySchedule',
       'StageActiveSince', 'ModelVersion','WorseLateCategory']

# %%
#create a new df with needed columns
loan = df_drop_m_val.drop(cols_del,axis=1)

# %%
#check the shape of loan df
loan.shape
# Out:
# (134529, 48)

# %% [markdown]
# ## Creating Target Variable
#
# Here, status is the variable which help us in creating target variable. The reason for not making status as target variable is that it has three unique values **current, Late and repaid**. There is no default feature but there is a feature **default date** which tells us when the borrower has defaulted means on which date the borrower defaulted. So, we will be combining **Status** and **Default date** features for creating target  variable.The reason we cannot simply treat Late as default because it also has some records in which actual status is Late but the user has never defaulted i.e., default date is null.
# So we will first filter out all the current status records because they are not matured yet they are current loans.

# %%
#columns in loan df
loan.columns
# Out:
# Index(['BidsPortfolioManager', 'BidsApi', 'BidsManual', 'NewCreditCustomer',
#        'LoanDate', 'FirstPaymentDate', 'MaturityDate_Original',
#        'MaturityDate_Last', 'VerificationType', 'LanguageCode', 'Age',
#        'Gender', 'Country', 'AppliedAmount', 'Amount', 'Interest',
#        'LoanDuration', 'MonthlyPayment', 'County', 'City', 'UseOfLoan',
#        'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'IncomeTotal', 'ExistingLiabilities',
#        'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash',
#        'MonthlyPaymentDay', 'LastPaymentOn', 'DefaultDate', 'Rating', 'Status',
#        'Restructured', 'CreditScoreEsMicroL', 'PrincipalPaymentsMade',
#        'InterestAndPenaltyPaymentsMade', 'PrincipalBalance',
#        'InterestAndPenaltyBalance', 'NoOfPreviousLoansBeforeLoan',
#        'AmountOfPreviousLoansBeforeLoan', 'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan'],
#       dtype='object')

# %%
#counts of each status categories 
loan.Status.value_counts()
# Out:
# Current    57135
# Late       45772
# Repaid     31622
# Name: Status, dtype: int64

# %%
# filtering out Current Status records
loan[loan.Status=='Current'].T
# Out:
#                                               491            523     \
# BidsPortfolioManager                            1355           1000
# BidsApi                                            0              0
# BidsManual                                   645.000          0.000
# NewCreditCustomer                               True          False
# LoanDate                                  2015-01-06     2015-01-07
# FirstPaymentDate                          2015-02-16     2015-03-06
# MaturityDate_Original                     2020-01-15     2020-02-06
# MaturityDate_Last                         2021-01-15     2021-11-08
# VerificationType                               3.000          4.000
# LanguageCode                                       4              1
# Age                                               28             27
# Gender                                         0.000          0.000
# Country                                           FI             EE
# AppliedAmount                               2000.000       1000.000
# Amount                                      2000.000       1000.000
# Interest                                      24.460         17.740
# LoanDuration                                      60             60
# MonthlyPayment                                63.900         28.170
# County                                  POHJOIS-SAVO  LÄÄNE-VIRUMAA
# City                                          KUOPIO    SÕMERU VALD
# UseOfLoan                                          7              7
# Education                                      5.000          4.000
# MaritalStatus                                  2.000          3.000
# EmploymentStatus                               3.000          3.000
# EmploymentDurationCurrentEmployer         UpTo2Years      UpTo1Year
# OccupationArea                                 6.000          1.000
# HomeOwnershipType                              1.000          6.000
# IncomeTotal                                 2097.000        560.000
# ExistingLiabilities                                1              8
# LiabilitiesTotal                             629.000       1327.370
# RefinanceLiabilities                               0              2
# DebtToIncome                                   3.050         47.560
# FreeCash                                    1404.100         43.670
# MonthlyPaymentDay                                 15              6
# LastPaymentOn                             2020-01-17     2020-01-08
# DefaultDate                                      NaN            NaN
# Rating                                             D              B
# Status                                       Current        Current
# Restructured                                    True           True
# CreditScoreEsMicroL                              NaN            NaN
# PrincipalPaymentsMade                       1387.570        608.050
# InterestAndPenaltyPaymentsMade              1845.640        638.670
# PrincipalBalance                             612.430        391.950
# InterestAndPenaltyBalance                      0.000          0.000
# NoOfPreviousLoansBeforeLoan                        0              1
# AmountOfPreviousLoansBeforeLoan                0.000       1300.000
# PreviousRepaymentsBeforeLoan                   0.000        187.870
# PreviousEarlyRepaymentsCountBeforeLoan             0              0
#
#                                             536           541     \
# BidsPortfolioManager                          2345          2045
# BidsApi                                          0             0
# BidsManual                                 655.000       955.000
# NewCreditCustomer                            False          True
# LoanDate                                2015-01-07    2015-01-08
# FirstPaymentDate                        2015-02-16    2015-02-20
# MaturityDate_Original                   2020-01-14    2020-01-20
# MaturityDate_Last                       2024-02-23    2021-01-04
# VerificationType                             3.000         3.000
# LanguageCode                                     1             4
# Age                                             29            25
# Gender                                       0.000         0.000
# Country                                         EE            FI
# AppliedAmount                             3000.000      3000.000
# Amount                                    3000.000      3000.000
# Interest                                    17.870        27.980
# LoanDuration                                    60            60
# MonthlyPayment                              84.720       102.120
# County                                    PÄRNUMAA  POHJOIS-SAVO
# City                                         PÄRNU        KUOPIO
# UseOfLoan                                        7             0
# Education                                    2.000         3.000
# MaritalStatus                                3.000         3.000
# EmploymentStatus                             3.000         3.000
# EmploymentDurationCurrentEmployer       UpTo3Years    UpTo5Years
# OccupationArea                               3.000        10.000
# HomeOwnershipType                            3.000         4.000
# IncomeTotal                                745.000      1530.000
# ExistingLiabilities                              4             4
# LiabilitiesTotal                           427.030       955.000
# RefinanceLiabilities                             0             0
# DebtToIncome                                27.480        36.410
# FreeCash                                   290.280       472.880
# MonthlyPaymentDay                               14            27
# LastPaymentOn                           2020-01-23    2020-01-20
# DefaultDate                                    NaN           NaN
# Rating                                           B             D
# Status                                     Current       Current
# Restructured                                  True          True
# CreditScoreEsMicroL                            NaN           NaN
# PrincipalPaymentsMade                     1270.420      1916.720
# InterestAndPenaltyPaymentsMade            1890.240      3144.210
# PrincipalBalance                          1729.580      1083.280
# InterestAndPenaltyBalance                    0.000         0.000
# NoOfPreviousLoansBeforeLoan                      1             0
# AmountOfPreviousLoansBeforeLoan           1000.000         0.000
# PreviousRepaymentsBeforeLoan               623.890         0.000
# PreviousEarlyRepaymentsCountBeforeLoan           0             0
#
#                                                 544         545     \
# BidsPortfolioManager                              1500        1275
# BidsApi                                              0           0
# BidsManual                                       0.000     225.000
# NewCreditCustomer                                 True       False
# LoanDate                                    2015-01-08  2015-01-08
# FirstPaymentDate                            2015-02-25  2015-02-11
# MaturityDate_Original                       2020-01-27  2020-01-13
# MaturityDate_Last                           2020-01-27  2021-02-11
# VerificationType                                 1.000       4.000
# LanguageCode                                         1           1
# Age                                                 30          39
# Gender                                           0.000       1.000
# Country                                             EE          EE
# AppliedAmount                                 1500.000    1500.000
# Amount                                        1500.000    1500.000
# Interest                                        29.250      27.710
# LoanDuration                                        60          60
# MonthlyPayment                                  52.840      51.440
# County                                           TARTU       TARTU
# City                                            KABINA       VÕNNU
# UseOfLoan                                            7           0
# Education                                        4.000       4.000
# MaritalStatus                                    2.000       1.000
# EmploymentStatus                                 5.000       3.000
# EmploymentDurationCurrentEmployer       MoreThan5Years  UpTo5Years
# OccupationArea                                   5.000      16.000
# HomeOwnershipType                                3.000       1.000
# IncomeTotal                                   1500.000     445.000
# ExistingLiabilities                                  2           3
# LiabilitiesTotal                               465.000     448.530
# RefinanceLiabilities                                 0           0
# DebtToIncome                                     4.520      30.890
# FreeCash                                       982.160      57.560
# MonthlyPaymentDay                                   25          11
# LastPaymentOn                               2019-12-27  2020-01-13
# DefaultDate                                        NaN         NaN
# Rating                                               D           D
# Status                                         Current     Current
# Restructured                                     False        True
# CreditScoreEsMicroL                                NaN         NaN
# PrincipalPaymentsMade                         1453.110     840.190
# InterestAndPenaltyPaymentsMade                1396.060    1466.170
# PrincipalBalance                                46.890     659.810
# InterestAndPenaltyBalance                        0.000       0.000
# NoOfPreviousLoansBeforeLoan                          0           1
# AmountOfPreviousLoansBeforeLoan                  0.000    2000.000
# PreviousRepaymentsBeforeLoan                     0.000    1361.780
# PreviousEarlyRepaymentsCountBeforeLoan               0           0
#
#                                                  548         583     \
# BidsPortfolioManager                               1500         470
# BidsApi                                               0           0
# BidsManual                                        0.000     530.000
# NewCreditCustomer                                  True       False
# LoanDate                                     2015-01-08  2015-01-09
# FirstPaymentDate                             2015-02-25  2015-03-05
# MaturityDate_Original                        2020-01-27  2020-02-05
# MaturityDate_Last                            2020-07-28  2022-08-05
# VerificationType                                  4.000       3.000
# LanguageCode                                          6           4
# Age                                                  47          68
# Gender                                            1.000       1.000
# Country                                              ES          FI
# AppliedAmount                                  1500.000    1000.000
# Amount                                         1500.000    1000.000
# Interest                                         73.730      18.100
# LoanDuration                                         60          60
# MonthlyPayment                                   99.810      28.780
# County                                  CASTILLA Y LEÓN      KUOPIO
# City                                          VILLATORO      KUOPIO
# UseOfLoan                                             7           2
# Education                                         4.000       4.000
# MaritalStatus                                     2.000       3.000
# EmploymentStatus                                  3.000       6.000
# EmploymentDurationCurrentEmployer            UpTo3Years  UpTo5Years
# OccupationArea                                   17.000       6.000
# HomeOwnershipType                                 3.000       1.000
# IncomeTotal                                    1206.000    1430.000
# ExistingLiabilities                                   5           3
# LiabilitiesTotal                                670.000     728.570
# RefinanceLiabilities                                  0           0
# DebtToIncome                                     33.900       7.610
# FreeCash                                        436.190     821.220
# MonthlyPaymentDay                                    25           5
# LastPaymentOn                                2020-01-02  2019-09-05
# DefaultDate                                         NaN         NaN
# Rating                                               HR           B
# Status                                          Current     Current
# Restructured                                       True        True
# CreditScoreEsMicroL                                  M5         NaN
# PrincipalPaymentsMade                           973.080     526.720
# InterestAndPenaltyPaymentsMade                 4643.170     593.400
# PrincipalBalance                                526.920     473.280
# InterestAndPenaltyBalance                         0.000      35.460
# NoOfPreviousLoansBeforeLoan                           0           1
# AmountOfPreviousLoansBeforeLoan                   0.000    2500.000
# PreviousRepaymentsBeforeLoan                      0.000     459.710
# PreviousEarlyRepaymentsCountBeforeLoan                0           1
#
#                                                       649         652     \
# BidsPortfolioManager                                    1325        2330
# BidsApi                                                    0           0
# BidsManual                                           175.000    7670.000
# NewCreditCustomer                                       True        True
# LoanDate                                          2015-01-16  2015-01-18
# FirstPaymentDate                                  2015-03-03  2015-03-16
# MaturityDate_Original                             2020-02-03  2020-02-17
# MaturityDate_Last                                 2020-05-15  2020-02-17
# VerificationType                                       3.000       4.000
# LanguageCode                                               6           1
# Age                                                       53          30
# Gender                                                 0.000       0.000
# Country                                                   ES          EE
# AppliedAmount                                       1500.000   10000.000
# Amount                                              1500.000   10000.000
# Interest                                              24.700      23.570
# LoanDuration                                              60          60
# MonthlyPayment                                        48.760     318.520
# County                                             BARCELONA       HARJU
# City                                    MONTORNÉS DEL VALLÉS     TALLINN
# UseOfLoan                                                  7           1
# Education                                              4.000       4.000
# MaritalStatus                                          3.000       3.000
# EmploymentStatus                                       3.000       5.000
# EmploymentDurationCurrentEmployer                  UpTo1Year  UpTo4Years
# OccupationArea                                         5.000       4.000
# HomeOwnershipType                                      2.000       4.000
# IncomeTotal                                          885.000    1050.000
# ExistingLiabilities                                        1           3
# LiabilitiesTotal                                     350.000     790.000
# RefinanceLiabilities                                       0           1
# DebtToIncome                                           5.510      69.860
# FreeCash                                             486.240       1.480
# MonthlyPaymentDay                                          3          15
# LastPaymentOn                                     2020-01-15  2020-01-20
# DefaultDate                                              NaN         NaN
# Rating                                                     D           C
# Status                                               Current     Current
# Restructured                                            True       False
# CreditScoreEsMicroL                                       M2         NaN
# PrincipalPaymentsMade                               1337.710    9720.060
# InterestAndPenaltyPaymentsMade                      1211.260    7346.460
# PrincipalBalance                                     162.290     279.940
# InterestAndPenaltyBalance                              0.000       0.000
# NoOfPreviousLoansBeforeLoan                                0           0
# AmountOfPreviousLoansBeforeLoan                        0.000       0.000
# PreviousRepaymentsBeforeLoan                           0.000       0.000
# PreviousEarlyRepaymentsCountBeforeLoan                     0           0
#
#                                                  654             680     \
# BidsPortfolioManager                               1870            2000
# BidsApi                                               0               0
# BidsManual                                     1830.000           0.000
# NewCreditCustomer                                  True           False
# LoanDate                                     2015-01-19      2015-01-21
# FirstPaymentDate                             2015-02-20      2015-03-10
# MaturityDate_Original                        2020-01-20      2020-02-10
# MaturityDate_Last                            2021-01-21      2021-05-10
# VerificationType                                  3.000           3.000
# LanguageCode                                          4               1
# Age                                                  55              32
# Gender                                            1.000           0.000
# Country                                              FI              EE
# AppliedAmount                                  3700.000        2000.000
# Amount                                         3700.000        2000.000
# Interest                                         22.010          26.110
# LoanDuration                                         60              60
# MonthlyPayment                                  114.540          66.680
# County                                  ETELÄ-POHJANMAA           SAARE
# City                                          SEINÄJOKI   TORNIMÄE KÜLA
# UseOfLoan                                             6               2
# Education                                         4.000           4.000
# MaritalStatus                                     1.000           3.000
# EmploymentStatus                                  3.000           3.000
# EmploymentDurationCurrentEmployer        MoreThan5Years  MoreThan5Years
# OccupationArea                                    7.000          15.000
# HomeOwnershipType                                 4.000           2.000
# IncomeTotal                                    1597.000         722.000
# ExistingLiabilities                                   3               3
# LiabilitiesTotal                                695.000         389.820
# RefinanceLiabilities                                  0               0
# DebtToIncome                                     19.380          28.600
# FreeCash                                        787.460         265.500
# MonthlyPaymentDay                                    20              10
# LastPaymentOn                                2020-01-21      2020-01-10
# DefaultDate                                         NaN             NaN
# Rating                                                C               C
# Status                                          Current         Current
# Restructured                                       True            True
# CreditScoreEsMicroL                                 NaN             NaN
# PrincipalPaymentsMade                          2607.820        1327.310
# InterestAndPenaltyPaymentsMade                 3005.320        1847.260
# PrincipalBalance                               1092.180         672.690
# InterestAndPenaltyBalance                         0.000           0.000
# NoOfPreviousLoansBeforeLoan                           0               1
# AmountOfPreviousLoansBeforeLoan                   0.000        1900.000
# PreviousRepaymentsBeforeLoan                      0.000         250.880
# PreviousEarlyRepaymentsCountBeforeLoan                0               0
#
#                                             688             692     \
# BidsPortfolioManager                          1100            2115
# BidsApi                                          0               0
# BidsManual                                   0.000        2385.000
# NewCreditCustomer                             True            True
# LoanDate                                2015-01-22      2015-01-22
# FirstPaymentDate                        2015-03-16      2015-03-09
# MaturityDate_Original                   2020-02-17      2020-02-10
# MaturityDate_Last                       2020-10-16      2020-02-10
# VerificationType                             1.000           4.000
# LanguageCode                                     4               1
# Age                                             43              52
# Gender                                       0.000           1.000
# Country                                         FI              EE
# AppliedAmount                             1100.000        4500.000
# Amount                                    1100.000        4500.000
# Interest                                    21.760          20.100
# LoanDuration                                    60              60
# MonthlyPayment                              33.900         134.480
# County                                  VASARAINEN           TARTU
# City                                    VASARAINEN    NÕGIARU KÜLA
# UseOfLoan                                        2               7
# Education                                    3.000           4.000
# MaritalStatus                                2.000           1.000
# EmploymentStatus                             3.000           3.000
# EmploymentDurationCurrentEmployer       UpTo2Years  MoreThan5Years
# OccupationArea                               6.000          16.000
# HomeOwnershipType                            1.000           1.000
# IncomeTotal                               3600.000         474.000
# ExistingLiabilities                              3               2
# LiabilitiesTotal                          1540.000         279.000
# RefinanceLiabilities                             0               1
# DebtToIncome                                 0.940          28.370
# FreeCash                                  2026.100          89.520
# MonthlyPaymentDay                               16               8
# LastPaymentOn                           2020-01-16      2020-01-08
# DefaultDate                                    NaN             NaN
# Rating                                           C               B
# Status                                     Current         Current
# Restructured                                  True           False
# CreditScoreEsMicroL                            NaN             NaN
# PrincipalPaymentsMade                      862.640        4382.700
# InterestAndPenaltyPaymentsMade             835.380        2708.550
# PrincipalBalance                           237.360         117.300
# InterestAndPenaltyBalance                    0.000           0.000
# NoOfPreviousLoansBeforeLoan                      0               0
# AmountOfPreviousLoansBeforeLoan              0.000           0.000
# PreviousRepaymentsBeforeLoan                 0.000           0.000
# PreviousEarlyRepaymentsCountBeforeLoan           0               0
#
#                                              737             768     \
# BidsPortfolioManager                            835            1000
# BidsApi                                           0               0
# BidsManual                                  165.000           0.000
# NewCreditCustomer                              True            True
# LoanDate                                 2015-01-25      2015-01-21
# FirstPaymentDate                         2015-02-25      2015-03-16
# MaturityDate_Original                    2020-01-27      2020-02-17
# MaturityDate_Last                        2023-05-22      2020-02-17
# VerificationType                              1.000           3.000
# LanguageCode                                      4               4
# Age                                              69              47
# Gender                                        1.000           1.000
# Country                                          FI              FI
# AppliedAmount                              1000.000        1000.000
# Amount                                     1000.000        1000.000
# Interest                                     33.320          33.320
# LoanDuration                                     60              60
# MonthlyPayment                               37.750          37.750
# County                                  KYMENLAAKSO       PIRKANMAA
# City                                       VALKEALA         TAMPERE
# UseOfLoan                                         7               6
# Education                                     2.000           4.000
# MaritalStatus                                 3.000           4.000
# EmploymentStatus                              6.000           3.000
# EmploymentDurationCurrentEmployer        UpTo5Years  MoreThan5Years
# OccupationArea                               17.000          17.000
# HomeOwnershipType                             3.000           4.000
# IncomeTotal                                1200.000        2300.000
# ExistingLiabilities                               1               1
# LiabilitiesTotal                            500.000         690.000
# RefinanceLiabilities                              0               0
# DebtToIncome                                  3.150           1.640
# FreeCash                                    662.250        1572.250
# MonthlyPaymentDay                                17              15
# LastPaymentOn                            2020-01-21      2020-01-15
# DefaultDate                                     NaN             NaN
# Rating                                            E               E
# Status                                      Current         Current
# Restructured                                   True           False
# CreditScoreEsMicroL                             NaN             NaN
# PrincipalPaymentsMade                       264.670         966.500
# InterestAndPenaltyPaymentsMade             1470.160        1087.360
# PrincipalBalance                            735.330          33.500
# InterestAndPenaltyBalance                     0.000           0.000
# NoOfPreviousLoansBeforeLoan                       0               0
# AmountOfPreviousLoansBeforeLoan               0.000           0.000
# PreviousRepaymentsBeforeLoan                  0.000           0.000
# PreviousEarlyRepaymentsCountBeforeLoan            0               0
#
#                                                           808         835     \
# BidsPortfolioManager                                        2000        1360
# BidsApi                                                        0           0
# BidsManual                                                 0.000     640.000
# NewCreditCustomer                                          False        True
# LoanDate                                              2015-01-20  2015-01-19
# FirstPaymentDate                                      2015-03-02  2015-02-25
# MaturityDate_Original                                 2020-02-03  2020-01-27
# MaturityDate_Last                                     2020-10-02  2020-01-27
# VerificationType                                           4.000       1.000
# LanguageCode                                                   1           4
# Age                                                           56          27
# Gender                                                     1.000       1.000
# Country                                                       EE          FI
# AppliedAmount                                           2000.000    2000.000
# Amount                                                  2000.000    2000.000
# Interest                                                  15.800      17.660
# LoanDuration                                                  60          60
# MonthlyPayment                                            55.090      57.080
# County                                             LÄÄNE-VIRUMAA   POHJANMAA
# City                                    SÕMERU VALD, NÄPI ALEVIK     KUUSAMO
# UseOfLoan                                                      0           7
# Education                                                  5.000       4.000
# MaritalStatus                                              1.000       1.000
# EmploymentStatus                                           3.000       3.000
# EmploymentDurationCurrentEmployer                 MoreThan5Years  UpTo5Years
# OccupationArea                                            15.000      17.000
# HomeOwnershipType                                          1.000       1.000
# IncomeTotal                                              900.000    2440.000
# ExistingLiabilities                                            6           2
# LiabilitiesTotal                                         617.570    1082.000
# RefinanceLiabilities                                           0           0
# DebtToIncome                                              44.740       2.340
# FreeCash                                                 227.340    1300.920
# MonthlyPaymentDay                                              2          25
# LastPaymentOn                                         2020-01-02  2020-01-02
# DefaultDate                                                  NaN         NaN
# Rating                                                         A           B
# Status                                                   Current     Current
# Restructured                                                True       False
# CreditScoreEsMicroL                                          NaN         NaN
# PrincipalPaymentsMade                                   1628.590    1950.530
# InterestAndPenaltyPaymentsMade                          1011.740    1034.550
# PrincipalBalance                                         371.410      49.470
# InterestAndPenaltyBalance                                  0.000       0.000
# NoOfPreviousLoansBeforeLoan                                    1           0
# AmountOfPreviousLoansBeforeLoan                         4000.000       0.000
# PreviousRepaymentsBeforeLoan                            1229.430       0.000
# PreviousEarlyRepaymentsCountBeforeLoan                         0           0
#
#                                                 837             838     \
# BidsPortfolioManager                              1000            3000
# BidsApi                                              0               0
# BidsManual                                       0.000           0.000
# NewCreditCustomer                                False            True
# LoanDate                                    2015-01-19      2015-01-19
# FirstPaymentDate                            2015-03-16      2015-02-20
# MaturityDate_Original                       2020-02-17      2020-01-20
# MaturityDate_Last                           2020-02-17      2023-09-11
# VerificationType                                 4.000           4.000
# LanguageCode                                         1               1
# Age                                                 40              51
# Gender                                           0.000           1.000
# Country                                             EE              EE
# AppliedAmount                                 1000.000        3000.000
# Amount                                        1000.000        3000.000
# Interest                                        15.510          23.330
# LoanDuration                                        60              60
# MonthlyPayment                                  27.390          95.140
# County                                       JÕGEVAMAA           TARTU
# City                                        KASSINURME           LAEVA
# UseOfLoan                                            7               2
# Education                                        4.000           5.000
# MaritalStatus                                    3.000           1.000
# EmploymentStatus                                 3.000           3.000
# EmploymentDurationCurrentEmployer       MoreThan5Years  MoreThan5Years
# OccupationArea                                   6.000          11.000
# HomeOwnershipType                                1.000           1.000
# IncomeTotal                                   1000.000         640.000
# ExistingLiabilities                                  6               3
# LiabilitiesTotal                               751.370         477.000
# RefinanceLiabilities                                 0               0
# DebtToIncome                                    47.880          50.330
# FreeCash                                       221.240          67.860
# MonthlyPaymentDay                                   15              20
# LastPaymentOn                               2020-01-16      2020-01-10
# DefaultDate                                        NaN             NaN
# Rating                                               A               C
# Status                                         Current         Current
# Restructured                                     False            True
# CreditScoreEsMicroL                                NaN             NaN
# PrincipalPaymentsMade                          976.160        1870.210
# InterestAndPenaltyPaymentsMade                 454.900        2302.260
# PrincipalBalance                                23.840        1129.790
# InterestAndPenaltyBalance                        0.000           0.000
# NoOfPreviousLoansBeforeLoan                          1               0
# AmountOfPreviousLoansBeforeLoan                500.000           0.000
# PreviousRepaymentsBeforeLoan                   442.560           0.000
# PreviousEarlyRepaymentsCountBeforeLoan               0               0
#
#                                             844         845     \
# BidsPortfolioManager                          1145           0
# BidsApi                                          0           0
# BidsManual                                1355.000     800.000
# NewCreditCustomer                            False        True
# LoanDate                                2015-01-17  2015-01-17
# FirstPaymentDate                        2015-02-20  2015-03-16
# MaturityDate_Original                   2020-01-20  2020-02-17
# MaturityDate_Last                       2024-12-27  2020-02-17
# VerificationType                             3.000       1.000
# LanguageCode                                     1           1
# Age                                             67          35
# Gender                                       1.000       0.000
# Country                                         EE          EE
# AppliedAmount                             2500.000     800.000
# Amount                                    2500.000     800.000
# Interest                                    20.640      25.960
# LoanDuration                                    60          60
# MonthlyPayment                              75.450      26.600
# County                                    VILJANDI    PÄRNUMAA
# City                                    TÄNASSILMA      KARUBA
# UseOfLoan                                        0           7
# Education                                    5.000       4.000
# MaritalStatus                                5.000       2.000
# EmploymentStatus                             3.000       3.000
# EmploymentDurationCurrentEmployer        UpTo1Year  UpTo3Years
# OccupationArea                              17.000       3.000
# HomeOwnershipType                            1.000       1.000
# IncomeTotal                                500.000    1000.000
# ExistingLiabilities                              6           4
# LiabilitiesTotal                           453.360     463.000
# RefinanceLiabilities                             4           0
# DebtToIncome                                32.180      10.260
# FreeCash                                    89.080     510.400
# MonthlyPaymentDay                               20          15
# LastPaymentOn                           2020-01-03  2020-01-15
# DefaultDate                                    NaN         NaN
# Rating                                           C           C
# Status                                     Current     Current
# Restructured                                  True       False
# CreditScoreEsMicroL                            NaN         NaN
# PrincipalPaymentsMade                      708.320     776.510
# InterestAndPenaltyPaymentsMade            1983.050     652.070
# PrincipalBalance                          1791.680      23.490
# InterestAndPenaltyBalance                    0.000       0.000
# NoOfPreviousLoansBeforeLoan                      1           0
# AmountOfPreviousLoansBeforeLoan           2600.000       0.000
# PreviousRepaymentsBeforeLoan               395.910       0.000
# PreviousEarlyRepaymentsCountBeforeLoan           0           0
#
#                                                 858         986     \
# BidsPortfolioManager                              2000        1300
# BidsApi                                              0           0
# BidsManual                                       0.000       0.000
# NewCreditCustomer                                False        True
# LoanDate                                    2015-01-16  2015-01-26
# FirstPaymentDate                            2015-03-05  2015-03-16
# MaturityDate_Original                       2020-02-05  2019-02-15
# MaturityDate_Last                           2021-01-11  2020-02-17
# VerificationType                                 4.000       4.000
# LanguageCode                                         1           1
# Age                                                 37          22
# Gender                                           1.000       0.000
# Country                                             EE          EE
# AppliedAmount                                 2000.000    1300.000
# Amount                                        2000.000    1300.000
# Interest                                        15.510      30.620
# LoanDuration                                        60          48
# MonthlyPayment                                  54.780      51.610
# County                                          JÕGEVA   JÕGEVAMAA
# City                                         PÕLTSAMAA  KAERA KÜLA
# UseOfLoan                                            0           2
# Education                                        4.000       4.000
# MaritalStatus                                    1.000       3.000
# EmploymentStatus                                 3.000       3.000
# EmploymentDurationCurrentEmployer       MoreThan5Years  UpTo3Years
# OccupationArea                                  17.000       3.000
# HomeOwnershipType                                1.000       2.000
# IncomeTotal                                    575.000     550.000
# ExistingLiabilities                                  6           1
# LiabilitiesTotal                               702.790     250.000
# RefinanceLiabilities                                 1           0
# DebtToIncome                                    55.750       9.380
# FreeCash                                         4.430     248.390
# MonthlyPaymentDay                                    5          15
# LastPaymentOn                               2020-01-10  2020-01-15
# DefaultDate                                        NaN         NaN
# Rating                                               A           D
# Status                                         Current     Current
# Restructured                                      True        True
# CreditScoreEsMicroL                                NaN         NaN
# PrincipalPaymentsMade                         1490.250    1253.930
# InterestAndPenaltyPaymentsMade                1096.870    1121.230
# PrincipalBalance                               509.750      46.070
# InterestAndPenaltyBalance                        0.000       0.000
# NoOfPreviousLoansBeforeLoan                          1           0
# AmountOfPreviousLoansBeforeLoan               2500.000       0.000
# PreviousRepaymentsBeforeLoan                   249.630       0.000
# PreviousEarlyRepaymentsCountBeforeLoan               0           0
#
#                                             989         1199        1261    \
# BidsPortfolioManager                          2600        1580           0
# BidsApi                                          0           0           0
# BidsManual                                   0.000     120.000    1200.000
# NewCreditCustomer                             True       False        True
# LoanDate                                2015-01-26  2015-01-28  2015-01-08
# FirstPaymentDate                        2015-03-10  2015-03-02  2015-02-10
# MaturityDate_Original                   2020-02-10  2020-02-03  2020-01-10
# MaturityDate_Last                       2024-12-16  2021-02-01  2021-04-27
# VerificationType                             4.000       4.000       1.000
# LanguageCode                                     1           6           3
# Age                                             41          46          48
# Gender                                       1.000       0.000       1.000
# Country                                         EE          ES          EE
# AppliedAmount                             2600.000    1700.000    1200.000
# Amount                                    2600.000    1700.000    1200.000
# Interest                                    16.680      31.120      24.470
# LoanDuration                                    60          60          60
# MonthlyPayment                              72.840      61.840      38.850
# County                                    PÄRNUMAA      MADRID       HARJU
# City                                    SAUGA VALD      MADRID     TALLINN
# UseOfLoan                                        2           7           8
# Education                                    4.000       4.000       5.000
# MaritalStatus                                4.000       3.000       1.000
# EmploymentStatus                             3.000       3.000       5.000
# EmploymentDurationCurrentEmployer       UpTo2Years  UpTo5Years  UpTo3Years
# OccupationArea                               9.000       1.000      18.000
# HomeOwnershipType                            8.000       7.000       7.000
# IncomeTotal                                850.000     985.000    1400.000
# ExistingLiabilities                              4           7           2
# LiabilitiesTotal                           643.000    1395.880     480.000
# RefinanceLiabilities                             0           2           0
# DebtToIncome                                32.450      60.680       7.060
# FreeCash                                   134.160      37.280     881.150
# MonthlyPaymentDay                               10           1          15
# LastPaymentOn                           2020-01-21  2020-01-02  2019-12-27
# DefaultDate                                    NaN         NaN         NaN
# Rating                                           A           E           C
# Status                                     Current     Current     Current
# Restructured                                  True        True        True
# CreditScoreEsMicroL                            NaN          M3         NaN
# PrincipalPaymentsMade                     1088.640    1199.090     722.810
# InterestAndPenaltyPaymentsMade            1609.740    1876.080    1085.870
# PrincipalBalance                          1511.360     500.910     477.190
# InterestAndPenaltyBalance                    0.000       0.000       0.000
# NoOfPreviousLoansBeforeLoan                      0           1           0
# AmountOfPreviousLoansBeforeLoan              0.000    1900.000       0.000
# PreviousRepaymentsBeforeLoan                 0.000     258.480       0.000
# PreviousEarlyRepaymentsCountBeforeLoan           0           0           0
#
#                                                 1265         1275    \
# BidsPortfolioManager                              1305          500
# BidsApi                                              0            0
# BidsManual                                    1695.000        0.000
# NewCreditCustomer                                False        False
# LoanDate                                    2015-01-08   2015-01-08
# FirstPaymentDate                            2015-03-09   2015-03-02
# MaturityDate_Original                       2020-02-07   2020-02-03
# MaturityDate_Last                           2020-02-07   2024-04-26
# VerificationType                                 3.000        4.000
# LanguageCode                                         3            1
# Age                                                 53           49
# Gender                                           1.000        1.000
# Country                                             EE           EE
# AppliedAmount                                 3000.000      500.000
# Amount                                        3000.000      500.000
# Interest                                        20.250       17.830
# LoanDuration                                        60           60
# MonthlyPayment                                  88.650       14.320
# County                                           HARJU     VILJANDI
# City                                           TALLINN  PEETRIMÕISA
# UseOfLoan                                            7            7
# Education                                        3.000        5.000
# MaritalStatus                                    4.000        1.000
# EmploymentStatus                                 3.000        3.000
# EmploymentDurationCurrentEmployer       MoreThan5Years    UpTo1Year
# OccupationArea                                   1.000       17.000
# ...
# InterestAndPenaltyBalance                        0.000           0.000
# NoOfPreviousLoansBeforeLoan                          0               0
# AmountOfPreviousLoansBeforeLoan                  0.000           0.000
# PreviousRepaymentsBeforeLoan                     0.000           0.000
# PreviousEarlyRepaymentsCountBeforeLoan               0               0
#
#                                             134298          134311  \
# BidsPortfolioManager                          3700               0
# BidsApi                                          0               0
# BidsManual                                   0.000        2500.000
# NewCreditCustomer                             True           False
# LoanDate                                2014-12-16      2014-12-17
# FirstPaymentDate                        2015-02-06      2015-02-05
# MaturityDate_Original                   2020-01-06      2020-01-06
# MaturityDate_Last                       2020-03-06      2024-11-11
# VerificationType                             4.000           4.000
# LanguageCode                                     1               1
# Age                                             25              38
# Gender                                       1.000           1.000
# Country                                         EE              EE
# AppliedAmount                             3700.000        2500.000
# Amount                                    3700.000        2500.000
# Interest                                    29.000          15.000
# LoanDuration                                    60              60
# MonthlyPayment                             134.410          66.770
# County                                       TARTU           HARJU
# City                                         TARTU         TALLINN
# UseOfLoan                                        2               2
# Education                                    4.000           4.000
# MaritalStatus                                3.000           1.000
# EmploymentStatus                             3.000           3.000
# EmploymentDurationCurrentEmployer       UpTo3Years  MoreThan5Years
# OccupationArea                               9.000          16.000
# HomeOwnershipType                            2.000           7.000
# IncomeTotal                                397.000         700.000
# ExistingLiabilities                              2               4
# LiabilitiesTotal                           280.000         555.690
# RefinanceLiabilities                             1               1
# DebtToIncome                                33.860          13.820
# FreeCash                                    12.590         353.230
# MonthlyPaymentDay                                6               5
# LastPaymentOn                           2020-01-06      2020-01-06
# DefaultDate                                    NaN             NaN
# Rating                                           F              AA
# Status                                     Current         Current
# Restructured                                 False            True
# CreditScoreEsMicroL                            NaN             NaN
# PrincipalPaymentsMade                     3473.930        2275.830
# InterestAndPenaltyPaymentsMade            3566.590        1091.150
# PrincipalBalance                           226.070         224.170
# InterestAndPenaltyBalance                    0.000           0.000
# NoOfPreviousLoansBeforeLoan                      0               1
# AmountOfPreviousLoansBeforeLoan              0.000        2200.000
# PreviousRepaymentsBeforeLoan                 0.000        1223.200
# PreviousEarlyRepaymentsCountBeforeLoan           0               0
#
#                                                134429  \
# BidsPortfolioManager                              560
# BidsApi                                             0
# BidsManual                                     40.000
# NewCreditCustomer                               False
# LoanDate                                   2014-12-29
# FirstPaymentDate                           2015-02-25
# MaturityDate_Original                      2019-01-25
# MaturityDate_Last                          2022-05-25
# VerificationType                                4.000
# LanguageCode                                        1
# Age                                                34
# Gender                                          0.000
# Country                                            EE
# AppliedAmount                                 600.000
# Amount                                        600.000
# Interest                                       30.000
# LoanDuration                                       48
# MonthlyPayment                                 23.350
# County                                  LÄÄNE-VIRUMAA
# City                                     VÄIKE-MAARJA
# UseOfLoan                                           2
# Education                                       2.000
# MaritalStatus                                   2.000
# EmploymentStatus                                3.000
# EmploymentDurationCurrentEmployer           UpTo1Year
# OccupationArea                                  6.000
# HomeOwnershipType                               1.000
# IncomeTotal                                  1200.000
# ExistingLiabilities                                 4
# LiabilitiesTotal                              791.330
# RefinanceLiabilities                                0
# DebtToIncome                                   15.360
# FreeCash                                      655.650
# MonthlyPaymentDay                                  25
# LastPaymentOn                              2019-12-27
# DefaultDate                                       NaN
# Rating                                              C
# Status                                        Current
# Restructured                                     True
# CreditScoreEsMicroL                               NaN
# PrincipalPaymentsMade                         288.830
# InterestAndPenaltyPaymentsMade                704.390
# PrincipalBalance                              311.170
# InterestAndPenaltyBalance                       0.000
# NoOfPreviousLoansBeforeLoan                         2
# AmountOfPreviousLoansBeforeLoan              7000.000
# PreviousRepaymentsBeforeLoan                 2436.060
# PreviousEarlyRepaymentsCountBeforeLoan              0
#
#                                                          134455  \
# BidsPortfolioManager                                       2175
# BidsApi                                                       0
# BidsManual                                             2725.000
# NewCreditCustomer                                          True
# LoanDate                                             2014-12-30
# FirstPaymentDate                                     2015-02-25
# MaturityDate_Original                                2020-01-27
# MaturityDate_Last                                    2020-01-27
# VerificationType                                          4.000
# LanguageCode                                                  1
# Age                                                          57
# Gender                                                    0.000
# Country                                                      EE
# AppliedAmount                                          4900.000
# Amount                                                 4900.000
# Interest                                                 29.000
# LoanDuration                                                 60
# MonthlyPayment                                          178.000
# County                                                  VÕRUMAA
# City                                    MÕNISTE VALD, SARU KÜLA
# UseOfLoan                                                     7
# Education                                                 4.000
# MaritalStatus                                             1.000
# EmploymentStatus                                          3.000
# EmploymentDurationCurrentEmployer                MoreThan5Years
# OccupationArea                                            3.000
# HomeOwnershipType                                         1.000
# IncomeTotal                                             583.000
# ExistingLiabilities                                           6
# LiabilitiesTotal                                        567.310
# RefinanceLiabilities                                          3
# DebtToIncome                                             34.130
# FreeCash                                                 14.000
# MonthlyPaymentDay                                            25
# LastPaymentOn                                        2019-12-27
# DefaultDate                                                 NaN
# Rating                                                        B
# Status                                                  Current
# Restructured                                              False
# CreditScoreEsMicroL                                         NaN
# PrincipalPaymentsMade                                  4748.290
# InterestAndPenaltyPaymentsMade                         4530.100
# PrincipalBalance                                        151.710
# InterestAndPenaltyBalance                                 0.000
# NoOfPreviousLoansBeforeLoan                                   0
# AmountOfPreviousLoansBeforeLoan                           0.000
# PreviousRepaymentsBeforeLoan                              0.000
# PreviousEarlyRepaymentsCountBeforeLoan                        0
#
#                                                 134483      134486  \
# BidsPortfolioManager                              1000         635
# BidsApi                                              0           0
# BidsManual                                       0.000    3465.000
# NewCreditCustomer                                 True        True
# LoanDate                                    2015-01-02  2015-01-02
# FirstPaymentDate                            2015-02-16  2015-02-12
# MaturityDate_Original                       2020-01-15  2020-01-13
# MaturityDate_Last                           2024-02-15  2021-12-15
# VerificationType                                 3.000       4.000
# LanguageCode                                         4           1
# Age                                                 47          31
# Gender                                           1.000       1.000
# Country                                             FI          EE
# AppliedAmount                                 1000.000    4100.000
# Amount                                        1000.000    4100.000
# Interest                                        21.760      50.620
# LoanDuration                                        60          60
# MonthlyPayment                                  30.400     200.730
# County                                       SATAKUNTA    VILJANDI
# City                                          KAUVATSA         KÕO
# UseOfLoan                                            7           6
# Education                                        3.000       4.000
# MaritalStatus                                    1.000       2.000
# EmploymentStatus                                 3.000       3.000
# EmploymentDurationCurrentEmployer       MoreThan5Years   UpTo1Year
# OccupationArea                                  17.000       3.000
# HomeOwnershipType                                1.000       7.000
# IncomeTotal                                   1500.000     630.000
# ExistingLiabilities                                  2           3
# LiabilitiesTotal                               750.000     612.000
# RefinanceLiabilities                                 0           2
# DebtToIncome                                     2.030      31.860
# FreeCash                                       719.600     179.270
# MonthlyPaymentDay                                   15          20
# LastPaymentOn                               2020-01-15  2020-01-15
# DefaultDate                                        NaN         NaN
# Rating                                               C          HR
# Status                                         Current     Current
# Restructured                                      True        True
# CreditScoreEsMicroL                                NaN         NaN
# PrincipalPaymentsMade                          946.610    2246.600
# InterestAndPenaltyPaymentsMade                 658.520    7375.770
# PrincipalBalance                                53.390    1853.400
# InterestAndPenaltyBalance                        0.000       0.000
# NoOfPreviousLoansBeforeLoan                          0           0
# AmountOfPreviousLoansBeforeLoan                  0.000       0.000
# PreviousRepaymentsBeforeLoan                     0.000       0.000
# PreviousEarlyRepaymentsCountBeforeLoan               0           0
#
#                                              134491
# BidsPortfolioManager                           2230
# BidsApi                                           0
# BidsManual                                 3770.000
# NewCreditCustomer                             False
# LoanDate                                 2015-01-03
# FirstPaymentDate                         2015-02-10
# MaturityDate_Original                    2020-01-10
# MaturityDate_Last                        2020-11-10
# VerificationType                              3.000
# LanguageCode                                      1
# Age                                              26
# Gender                                        1.000
# Country                                          EE
# AppliedAmount                              6000.000
# Amount                                     6000.000
# Interest                                     34.000
# LoanDuration                                     60
# MonthlyPayment                              231.610
# County                                      VÕRUMAA
# City                                          MISSO
# UseOfLoan                                         7
# Education                                     4.000
# MaritalStatus                                 2.000
# EmploymentStatus                              6.000
# EmploymentDurationCurrentEmployer       TrialPeriod
# OccupationArea                                1.000
# HomeOwnershipType                             1.000
# IncomeTotal                                 629.000
# ExistingLiabilities                               2
# LiabilitiesTotal                            352.880
# RefinanceLiabilities                              0
# DebtToIncome                                 36.820
# FreeCash                                    147.390
# MonthlyPaymentDay                                10
# LastPaymentOn                            2020-01-10
# DefaultDate                                     NaN
# Rating                                           HR
# Status                                      Current
# Restructured                                   True
# CreditScoreEsMicroL                             NaN
# PrincipalPaymentsMade                      4300.670
# InterestAndPenaltyPaymentsMade             7593.690
# PrincipalBalance                           1699.330
# InterestAndPenaltyBalance                     0.000
# NoOfPreviousLoansBeforeLoan                       1
# AmountOfPreviousLoansBeforeLoan            2800.000
# PreviousRepaymentsBeforeLoan                302.830
# PreviousEarlyRepaymentsCountBeforeLoan            0
#
# [48 rows x 57135 columns]

# %% [markdown]
# Now, we will create new target variable in which 0 will be assigned when default date is null means borrower has never defaulted while 1 in case default date is present.

# %%
# for null value replacement: 
loan['DefaultDate'].replace(np.nan, 0,inplace=True)

#for String Date values replacement:  
for i in loan.DefaultDate:
    if len(str(i))>1:
        loan.DefaultDate.replace(i,1,inplace=True)

# %%
loan.DefaultDate.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: DefaultDate, dtype: int64

# %%
# check the counts of default and nondefault 
loan.DefaultDate.value_counts()
# Out:
# 0    91614
# 1    42915
# Name: DefaultDate, dtype: int64

# %%
# let's drop the status columns 
loan.drop(columns='Status',axis=1,inplace = True)

# %%
loan.head().T
# Out:
#                                                  0               1  \
# BidsPortfolioManager                             0               0
# BidsApi                                          0               0
# BidsManual                                 115.041         140.606
# NewCreditCustomer                             True           False
# LoanDate                                2009-06-16      2009-06-15
# FirstPaymentDate                        2009-07-27      2009-07-15
# MaturityDate_Original                   2010-06-25      2009-07-15
# MaturityDate_Last                       2010-06-25      2009-07-15
# VerificationType                             2.000           2.000
# LanguageCode                                     1               1
# Age                                             61              48
# Gender                                       1.000           1.000
# Country                                         EE              EE
# AppliedAmount                              319.558         191.735
# Amount                                     115.041         140.606
# Interest                                    30.000          25.000
# LoanDuration                                    12               1
# MonthlyPayment                                 NaN             NaN
# County                                       HARJU        IDA-VIRU
# City                                       TALLINN    KOHTLA-JARVE
# UseOfLoan                                        7               7
# Education                                    3.000           5.000
# MaritalStatus                                1.000           4.000
# EmploymentStatus                             3.000           3.000
# EmploymentDurationCurrentEmployer       UpTo3Years  MoreThan5Years
# OccupationArea                               7.000          16.000
# HomeOwnershipType                              NaN             NaN
# IncomeTotal                              10500.000       10800.000
# ExistingLiabilities                              0               0
# LiabilitiesTotal                             0.000           0.000
# RefinanceLiabilities                             0               0
# DebtToIncome                                 0.000           0.000
# FreeCash                                     0.000           0.000
# MonthlyPaymentDay                               25              15
# LastPaymentOn                           2010-07-06      2009-07-07
# DefaultDate                                      0               0
# Rating                                         NaN             NaN
# Restructured                                 False           False
# CreditScoreEsMicroL                            NaN             NaN
# PrincipalPaymentsMade                      115.041         140.606
# InterestAndPenaltyPaymentsMade              20.422           2.023
# PrincipalBalance                             0.000           0.000
# InterestAndPenaltyBalance                    0.000           0.000
# NoOfPreviousLoansBeforeLoan                      1               2
# AmountOfPreviousLoansBeforeLoan             83.085         255.647
# PreviousRepaymentsBeforeLoan                 0.000         258.626
# PreviousEarlyRepaymentsCountBeforeLoan           0               0
#
#                                                  2           3           4
# BidsPortfolioManager                             0           0           0
# BidsApi                                          0           0           0
# BidsManual                                 319.558      57.520     319.558
# NewCreditCustomer                             True        True        True
# LoanDate                                2009-06-15  2009-06-15  2009-06-14
# FirstPaymentDate                        2009-07-27  2009-07-15  2009-07-27
# MaturityDate_Original                   2011-02-25  2010-09-15  2010-06-25
# MaturityDate_Last                       2014-05-13  2010-09-15  2010-06-25
# VerificationType                             2.000       2.000       2.000
# LanguageCode                                     1           1           1
# Age                                             58          23          25
# Gender                                       1.000       1.000       1.000
# Country                                         EE          EE          EE
# AppliedAmount                              319.558     127.823     319.558
# Amount                                     319.541      57.520     319.544
# Interest                                    25.000      45.000      30.000
# LoanDuration                                    20          15          12
# MonthlyPayment                                 NaN         NaN         NaN
# County                                       PÄRNU       HARJU       TARTU
# City                                         PÄRNU    PALDISKI       TARTU
# UseOfLoan                                        2           0           6
# Education                                    4.000       2.000       4.000
# MaritalStatus                                1.000       3.000       2.000
# EmploymentStatus                             3.000         NaN       3.000
# EmploymentDurationCurrentEmployer       UpTo4Years  UpTo2Years  UpTo2Years
# OccupationArea                               9.000       1.000       7.000
# HomeOwnershipType                              NaN         NaN         NaN
# IncomeTotal                               7000.000   11600.000    6800.000
# ExistingLiabilities                              0           0           0
# LiabilitiesTotal                             0.000       0.000       0.000
# RefinanceLiabilities                             0           0           0
# DebtToIncome                                 0.000       0.000       0.000
# FreeCash                                     0.000       0.000       0.000
# MonthlyPaymentDay                               25          15          25
# LastPaymentOn                           2012-10-01  2010-09-15  2015-07-16
# DefaultDate                                      1           0           1
# Rating                                         NaN         NaN         NaN
# Restructured                                  True       False       False
# CreditScoreEsMicroL                            NaN         NaN         NaN
# PrincipalPaymentsMade                      203.191      57.520     319.544
# InterestAndPenaltyPaymentsMade              59.763      18.732     220.420
# PrincipalBalance                           116.350       0.000       0.000
# InterestAndPenaltyBalance                  414.070       0.000       0.000
# NoOfPreviousLoansBeforeLoan                      0           1           1
# AmountOfPreviousLoansBeforeLoan              0.000     134.214     146.997
# PreviousRepaymentsBeforeLoan                 0.000       0.000       0.000
# PreviousEarlyRepaymentsCountBeforeLoan           0           0           0

# %%
# let's drop the DefaultDate column
loan.drop(columns='DefaultDate',axis =1,inplace=True)

# %%
loan.shape
# Out:
# (134529, 46)

# %% [markdown]
# ## checking datatype of all features
# In this step we will see any data type mismatch

# %%
#check the info for dtypes of features
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134529 entries, 0 to 134528
# Data columns (total 46 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   BidsPortfolioManager                    134529 non-null  int64
#  1   BidsApi                                 134529 non-null  int64
#  2   BidsManual                              134529 non-null  float64
#  3   NewCreditCustomer                       134529 non-null  bool
#  4   LoanDate                                134529 non-null  object
#  5   FirstPaymentDate                        134529 non-null  object
#  6   MaturityDate_Original                   134529 non-null  object
#  7   MaturityDate_Last                       134529 non-null  object
#  8   VerificationType                        134484 non-null  float64
#  9   LanguageCode                            134529 non-null  int64
#  10  Age                                     134529 non-null  int64
#  11  Gender                                  134484 non-null  float64
#  12  Country                                 134529 non-null  object
#  13  AppliedAmount                           134529 non-null  float64
#  14  Amount                                  134529 non-null  float64
#  15  Interest                                134529 non-null  float64
#  16  LoanDuration                            134529 non-null  int64
#  17  MonthlyPayment                          127844 non-null  float64
#  18  County                                  97689 non-null   object
#  19  City                                    124735 non-null  object
#  20  UseOfLoan                               134529 non-null  int64
#  21  Education                               134484 non-null  float64
#  22  MaritalStatus                           134484 non-null  float64
#  23  EmploymentStatus                        134332 non-null  float64
#  24  EmploymentDurationCurrentEmployer       133653 non-null  object
#  25  OccupationArea                          134443 non-null  float64
#  26  HomeOwnershipType                       132877 non-null  float64
#  27  IncomeTotal                             134529 non-null  float64
#  28  ExistingLiabilities                     134529 non-null  int64
#  29  LiabilitiesTotal                        134529 non-null  float64
#  30  RefinanceLiabilities                    134529 non-null  int64
#  31  DebtToIncome                            134484 non-null  float64
#  32  FreeCash                                134484 non-null  float64
#  33  MonthlyPaymentDay                       134529 non-null  int64
#  34  LastPaymentOn                           124998 non-null  object
#  35  Rating                                  131799 non-null  object
#  36  Restructured                            134529 non-null  bool
#  37  CreditScoreEsMicroL                     104955 non-null  object
#  38  PrincipalPaymentsMade                   134529 non-null  float64
#  39  InterestAndPenaltyPaymentsMade          134529 non-null  float64
#  40  PrincipalBalance                        134529 non-null  float64
#  41  InterestAndPenaltyBalance               134529 non-null  float64
#  42  NoOfPreviousLoansBeforeLoan             134529 non-null  int64
#  43  AmountOfPreviousLoansBeforeLoan         134529 non-null  float64
#  44  PreviousRepaymentsBeforeLoan            91368 non-null   float64
#  45  PreviousEarlyRepaymentsCountBeforeLoan  134529 non-null  int64
# dtypes: bool(2), float64(22), int64(11), object(11)
# memory usage: 45.4+ MB

# %% [markdown]
# ># NOTE :
# - done some process after the visualization for better understanding

# %% [markdown]
# - First we will delete all the features related to date as it is not a time series analysis so these features will not help in predicting target variable.
# - As we can see in numeric column distribution there are many columns which are present as numeric but they are actually categorical as per data description such as Verification Type, Language Code, Gender, Use of Loan, Education, Marital Status,EmployementStatus, OccupationArea etc.
# - So we will convert these features to categorical features

# %% [markdown]
# Now we will check the distribution of different categorical variables

# %%
# for VerificationType value replacement
'''
0 Not set ,1 Income unverified ,2 Income unverified, 
cross-referenced by phone, 3 Income verified ,4 Income and expenses verified
'''
loan.VerificationType.replace({0.0:'Not set',
                               1.0:'Income unverified',
                               2.0:'Income unverified',
                               3.0:'Income verified',
                               4.0:'Income and expenses verified'},
                               inplace=True)

# %%
# check the val counts
loan.VerificationType.value_counts()
# Out:
# Income and expenses verified    74572
# Income unverified               50476
# Income verified                  9428
# Not set                             8
# Name: VerificationType, dtype: int64

# %%
#Gender value replacement
'''
0 Male 1 Woman 2 Undefined
'''

loan.Gender.replace({0.0:'Male',1.0:'Female',2.0:'Undefined'},inplace = True)

# %%
# check the val counts
loan.Gender.value_counts()
# Out:
# Male         85650
# Female       38213
# Undefined    10621
# Name: Gender, dtype: int64

# %%
#LanguageCode value replacement
'''
1 Estonian 2 English 3 Russian 4 Finnish 5 German 6 Spanish 9 Slovakian
'''

loan.LanguageCode.replace({1:'Estonian',2:'English',3:'Russian',4:'Finnish',
                               5:'German',6:'Spanish',9:'Slovakian'},inplace=True)

loan.LanguageCode.value_counts()
# Out:
# Estonian     64299
# Finnish      32155
# Spanish      24103
# Russian      12694
# English        967
# Slovakian      295
# 22               6
# German           5
# 15               1
# 10               1
# 13               1
# 7                1
# 21               1
# Name: LanguageCode, dtype: int64

# %% [markdown]
# As we can see from above in language code w ehave only descriptions for values 1,2,3,4,5,6, and 9 but it has other values too like 21,22,15,13,10 and 7 but they are very less it may happen they are local language codes whose decription is not present so we will be treated all these values as others

# %%
# code for LanguageCode value replacement
loan.LanguageCode.replace({22:'other',21:'other',7:'other',
                           15:'other',10:'other',13:'other'},inplace = True)

# %%
# check the val counts
loan.LanguageCode.value_counts()
# Out:
# Estonian     64299
# Finnish      32155
# Spanish      24103
# Russian      12694
# English        967
# Slovakian      295
# other           11
# German           5
# Name: LanguageCode, dtype: int64

# %% [markdown]
# As we can see from above stats most of the loans are -1 category whose description is not avaialble in Bondoro website so we have dig deeper to find that in Bondora most of the loans happened for which purpose so we find in Bondora [Statistics Page](https://www.bondora.com/en/public-statistics) most of the loans around 34.81% are for Not set purpose. so we will encode -1 as Not set category

# %%
#for useofloan columns value replacement
loan.UseOfLoan.replace({-1:'Not set category',0:'Loan consolidation',1:'Real estate',2:'Home improvement',
                        3:'Business',4:'Education',5:'Travel',6:'Vehicle',7:'Other',8:'Health',
                        101:'Working capital financing',102:'Purchase of machinery equipment',
                        103:'Renovation of real estate',104:'Accounts receivable financing',
                        105:'Acquisition of means of transport',106:'Construction finance',
                        107:'Acquisition of stocks',108:'Acquisition of real estate',
                        109:'Guaranteeing obligation',110:'Other business'}, inplace = True)

# %%
# check the val counts
loan.UseOfLoan.value_counts()
# Out:
# Not set category                   97946
# Other                               9698
# Home improvement                    9191
# Loan consolidation                  6914
# Vehicle                             3150
# Business                            1950
# Travel                              1787
# Health                              1519
# Education                           1366
# Real estate                          955
# Purchase of machinery equipment       21
# Other business                        17
# Accounts receivable financing          6
# Working capital financing              5
# Acquisition of stocks                  2
# Acquisition of real estate             1
# Construction finance                   1
# Name: UseOfLoan, dtype: int64

# %%
# code for Education value replacement
loan.Education.replace({1:'Primary',2:'Basic education',3:'Vocational education',
                        4:'Secondary education',5:'Higher education'},
                       inplace =True)
loan.Education.value_counts()
# Out:
# Secondary education     51330
# Higher education        35398
# Vocational education    29260
# Primary                 12057
# Basic education          6427
# 0.0                         8
# -1.0                        4
# Name: Education, dtype: int64

# %% [markdown]
# Again as we can see from above description for -1 and 0 in case of education is not present so we will encode them as Not_present as we dont know anything about them.

# %%
#  code for -1 and 0 in education column
loan.Education.replace({-1:'Not_present',0:'Not_present'},inplace =True)
loan.Education.value_counts()
# Out:
# Secondary education     51330
# Higher education        35398
# Vocational education    29260
# Primary                 12057
# Basic education          6427
# Not_present                12
# Name: Education, dtype: int64

# %%
# code here for MaritalStatus column value replacemnet
loan.MaritalStatus.replace({1:'Married',2:'Cohabitant',3:'Single',4:'Divorced',5:'Widow'},
                           inplace= True)

loan.MaritalStatus.value_counts()
# Out:
# -1.0          97946
# Single        12400
# Married       10752
# Cohabitant     9400
# Divorced       3377
# Widow           601
# 0.0               8
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# Again Marital status of value 0 and -1 has no description so we will encode them as Not_specified

# %%
# code for -1 and 0
loan.MaritalStatus.replace({-1:'Not_specified',0:'Not_specified'},inplace = True)
loan.MaritalStatus.value_counts()
# Out:
# Not_specified    97954
# Single           12400
# Married          10752
# Cohabitant        9400
# Divorced          3377
# Widow              601
# Name: MaritalStatus, dtype: int64

# %%
#EmploymentStatus column value replacement
loan.EmploymentStatus.replace({1:'Unemployed',2:'Partially employed',3:'Fully employed',
                               4:'Self-employed',5:'Entrepreneur',6:'Retiree'},inplace = True)

# %%
#NewCreditCustome column value replacement
'''Did the customer have prior credit history in Bondora
0 Customer had at least 3 months of credit history in Bondora 
1 No prior credit history in Bondora
'''
loan.NewCreditCustomer.replace({True:0,False:1},inplace = True)

# %%
#Restructured column value replacement

# The original maturity date of the loan has been increased by more than 60 day

loan.Restructured.replace({True:0,False:1},inplace = True)

# %%
#OccupationArea column value replacement
loan.OccupationArea.replace({1:'Other',2:'Mining',3:'Processing',4:'Energy',5:'Utilities',6:'Construction',
                             7:'Retail and wholesale',8:'Transport and warehousing',9:'Hospitality and catering',
                             10:'Info and telecom',11:'Finance and insurance',12:'Real-estate',13:'Research',
                             14:'Administrative',15:'Civil service & military',16:'Education',
                             17:'Healthcare and social help',18:'Art and entertainment',19:'Agriculture,forestry and fishing'},
                            inplace = True)

# %%
# HomeOwnershipType column value replacement
loan.HomeOwnershipType.replace({0:'Homeless',1:'Owner',2:'Living with parents',3:'Tenant, pre-furnished property',
                                4:'Tenant, unfurnished property',5:'Council house',6:'Joint tenant',
                                7:'Joint ownership',8:'Mortgage',9:'Owner with encumbrance',
                                10:'Other'},inplace = True)

# %%
#EmploymentStatus values replacement
loan.EmploymentStatus.replace({-1:'Not_specified',0:'Not_specified'},inplace = True)


#OccupationArea columns value replacement
loan.OccupationArea.replace({-1:'Not_specified',0:'Not_specified'},inplace = True)

#HomeOwnershipType columns value replacement
loan.HomeOwnershipType.replace({-1:'Not_specified'},inplace = True)

# %%
#counts of EmploymentStatus 
loan.EmploymentStatus.value_counts()
# Out:
# Not_specified         97978
# Fully employed        30060
# Entrepreneur           2007
# Retiree                1800
# Self-employed          1303
# Partially employed     1184
# Name: EmploymentStatus, dtype: int64

# %%
#counts of OccupationArea 
loan.OccupationArea.value_counts()
# Out:
# Not_specified                       98008
# Other                                8421
# Retail and wholesale                 3587
# Construction                         3312
# Processing                           3198
# Transport and warehousing            2462
# Healthcare and social help           2424
# Hospitality and catering             2262
# Info and telecom                     1933
# Civil service & military             1684
# Education                            1430
# Finance and insurance                1148
# Agriculture,forestry and fishing     1000
# Administrative                        843
# Art and entertainment                 619
# Energy                                587
# Research                              564
# Real-estate                           477
# Utilities                             362
# Mining                                122
# Name: OccupationArea, dtype: int64

# %%
#counts of Restructured
loan.Restructured.value_counts()
# Out:
# 1    106900
# 0     27629
# Name: Restructured, dtype: int64

# %%
#counts of NewCreditCustomer
loan.NewCreditCustomer.value_counts()
# Out:
# 0    77808
# 1    56721
# Name: NewCreditCustomer, dtype: int64

# %%
#counts of HomeOwnershipType
loan.HomeOwnershipType.value_counts()
# Out:
# Owner                             47334
# Tenant, pre-furnished property    29579
# Living with parents               20780
# Mortgage                          15457
# Other                              7956
# Tenant, unfurnished property       4582
# Joint ownership                    3337
# Joint tenant                       1618
# Council house                      1442
# Owner with encumbrance              743
# Homeless                             46
# Not_specified                         3
# Name: HomeOwnershipType, dtype: int64

# %%
loan.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer    LoanDate  \
# 0                     0        0     115.041                  0  2009-06-16
# 1                     0        0     140.606                  1  2009-06-15
# 2                     0        0     319.558                  0  2009-06-15
# 3                     0        0      57.520                  0  2009-06-15
# 4                     0        0     319.558                  0  2009-06-14
#
#   FirstPaymentDate MaturityDate_Original MaturityDate_Last   VerificationType  \
# 0       2009-07-27            2010-06-25        2010-06-25  Income unverified
# 1       2009-07-15            2009-07-15        2009-07-15  Income unverified
# 2       2009-07-27            2011-02-25        2014-05-13  Income unverified
# 3       2009-07-15            2010-09-15        2010-09-15  Income unverified
# 4       2009-07-27            2010-06-25        2010-06-25  Income unverified
#
#   LanguageCode  Age  Gender Country  AppliedAmount  Amount  Interest  \
# 0     Estonian   61  Female      EE        319.558 115.041    30.000
# 1     Estonian   48  Female      EE        191.735 140.606    25.000
# 2     Estonian   58  Female      EE        319.558 319.541    25.000
# 3     Estonian   23  Female      EE        127.823  57.520    45.000
# 4     Estonian   25  Female      EE        319.558 319.544    30.000
#
#    LoanDuration  MonthlyPayment    County          City           UseOfLoan  \
# 0            12             NaN     HARJU       TALLINN               Other
# 1             1             NaN  IDA-VIRU  KOHTLA-JARVE               Other
# 2            20             NaN     PÄRNU         PÄRNU    Home improvement
# 3            15             NaN     HARJU      PALDISKI  Loan consolidation
# 4            12             NaN     TARTU         TARTU             Vehicle
#
#               Education MaritalStatus EmploymentStatus  \
# 0  Vocational education       Married   Fully employed
# 1      Higher education      Divorced   Fully employed
# 2   Secondary education       Married   Fully employed
# 3       Basic education        Single              NaN
# 4   Secondary education    Cohabitant   Fully employed
#
#   EmploymentDurationCurrentEmployer            OccupationArea  \
# 0                        UpTo3Years      Retail and wholesale
# 1                    MoreThan5Years                 Education
# 2                        UpTo4Years  Hospitality and catering
# 3                        UpTo2Years                     Other
# 4                        UpTo2Years      Retail and wholesale
#
#   HomeOwnershipType  IncomeTotal  ExistingLiabilities  LiabilitiesTotal  \
# 0               NaN    10500.000                    0             0.000
# 1               NaN    10800.000                    0             0.000
# 2               NaN     7000.000                    0             0.000
# 3               NaN    11600.000                    0             0.000
# 4               NaN     6800.000                    0             0.000
#
#    RefinanceLiabilities  DebtToIncome  FreeCash  MonthlyPaymentDay  \
# 0                     0         0.000     0.000                 25
# 1                     0         0.000     0.000                 15
# 2                     0         0.000     0.000                 25
# 3                     0         0.000     0.000                 15
# 4                     0         0.000     0.000                 25
#
#   LastPaymentOn Rating  Restructured CreditScoreEsMicroL  \
# 0    2010-07-06    NaN             1                 NaN
# 1    2009-07-07    NaN             1                 NaN
# 2    2012-10-01    NaN             0                 NaN
# 3    2010-09-15    NaN             1                 NaN
# 4    2015-07-16    NaN             1                 NaN
#
#    PrincipalPaymentsMade  InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                115.041                          20.422             0.000
# 1                140.606                           2.023             0.000
# 2                203.191                          59.763           116.350
# 3                 57.520                          18.732             0.000
# 4                319.544                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0

# %% [markdown]
# # FEATURE ENGINEERING

# %%
# CHANGE DTYPES AND MAKE NEW COLUMNS

# %%
loan.MaturityDate_Last=pd.to_datetime(loan['MaturityDate_Last'])
loan.LoanDate=pd.to_datetime(loan['LoanDate'])
loan.FirstPaymentDate=pd.to_datetime(loan['FirstPaymentDate'])
loan.MaturityDate_Original=pd.to_datetime(loan['MaturityDate_Original'])
loan.LastPaymentOn=pd.to_datetime(loan['LastPaymentOn'])

# %%
loan['MaturityDate_Last_year'] = loan.MaturityDate_Last.dt.year
loan['MaturityDate_Last_month'] = loan.MaturityDate_Last.dt.month
loan['MaturityDate_Last_day'] = loan.MaturityDate_Last.dt.day

loan['LoanDate_year']=loan.LoanDate.dt.year
loan['LoanDate_month']=loan.LoanDate.dt.month
loan['LoanDate_day']=loan.LoanDate.dt.day

loan['FirstPaymentDate_year']=loan.FirstPaymentDate.dt.year
loan['FirstPaymentDate_month']=loan.FirstPaymentDate.dt.month
loan['FirstPaymentDate_day']=loan.FirstPaymentDate.dt.day

loan['MaturityDate_Original_year']=loan.MaturityDate_Original.dt.year
loan['MaturityDate_Original_month']=loan.MaturityDate_Original.dt.month
loan['MaturityDate_Original_day']=loan.MaturityDate_Original.dt.day

loan['LastPaymentOn_year']=loan.LastPaymentOn.dt.year
loan['LastPaymentOn_month']=loan.LastPaymentOn.dt.month
loan['LastPaymentOn_day']=loan.LastPaymentOn.dt.day

# %%
loan.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer   LoanDate  \
# 0                     0        0     115.041                  0 2009-06-16
# 1                     0        0     140.606                  1 2009-06-15
# 2                     0        0     319.558                  0 2009-06-15
# 3                     0        0      57.520                  0 2009-06-15
# 4                     0        0     319.558                  0 2009-06-14
#
#   FirstPaymentDate MaturityDate_Original MaturityDate_Last   VerificationType  \
# 0       2009-07-27            2010-06-25        2010-06-25  Income unverified
# 1       2009-07-15            2009-07-15        2009-07-15  Income unverified
# 2       2009-07-27            2011-02-25        2014-05-13  Income unverified
# 3       2009-07-15            2010-09-15        2010-09-15  Income unverified
# 4       2009-07-27            2010-06-25        2010-06-25  Income unverified
#
#   LanguageCode  Age  Gender Country  AppliedAmount  Amount  Interest  \
# 0     Estonian   61  Female      EE        319.558 115.041    30.000
# 1     Estonian   48  Female      EE        191.735 140.606    25.000
# 2     Estonian   58  Female      EE        319.558 319.541    25.000
# 3     Estonian   23  Female      EE        127.823  57.520    45.000
# 4     Estonian   25  Female      EE        319.558 319.544    30.000
#
#    LoanDuration  MonthlyPayment    County          City           UseOfLoan  \
# 0            12             NaN     HARJU       TALLINN               Other
# 1             1             NaN  IDA-VIRU  KOHTLA-JARVE               Other
# 2            20             NaN     PÄRNU         PÄRNU    Home improvement
# 3            15             NaN     HARJU      PALDISKI  Loan consolidation
# 4            12             NaN     TARTU         TARTU             Vehicle
#
#               Education MaritalStatus EmploymentStatus  \
# 0  Vocational education       Married   Fully employed
# 1      Higher education      Divorced   Fully employed
# 2   Secondary education       Married   Fully employed
# 3       Basic education        Single              NaN
# 4   Secondary education    Cohabitant   Fully employed
#
#   EmploymentDurationCurrentEmployer            OccupationArea  \
# 0                        UpTo3Years      Retail and wholesale
# 1                    MoreThan5Years                 Education
# 2                        UpTo4Years  Hospitality and catering
# 3                        UpTo2Years                     Other
# 4                        UpTo2Years      Retail and wholesale
#
#   HomeOwnershipType  IncomeTotal  ExistingLiabilities  LiabilitiesTotal  \
# 0               NaN    10500.000                    0             0.000
# 1               NaN    10800.000                    0             0.000
# 2               NaN     7000.000                    0             0.000
# 3               NaN    11600.000                    0             0.000
# 4               NaN     6800.000                    0             0.000
#
#    RefinanceLiabilities  DebtToIncome  FreeCash  MonthlyPaymentDay  \
# 0                     0         0.000     0.000                 25
# 1                     0         0.000     0.000                 15
# 2                     0         0.000     0.000                 25
# 3                     0         0.000     0.000                 15
# 4                     0         0.000     0.000                 25
#
#   LastPaymentOn Rating  Restructured CreditScoreEsMicroL  \
# 0    2010-07-06    NaN             1                 NaN
# 1    2009-07-07    NaN             1                 NaN
# 2    2012-10-01    NaN             0                 NaN
# 3    2010-09-15    NaN             1                 NaN
# 4    2015-07-16    NaN             1                 NaN
#
#    PrincipalPaymentsMade  InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                115.041                          20.422             0.000
# 1                140.606                           2.023             0.000
# 2                203.191                          59.763           116.350
# 3                 57.520                          18.732             0.000
# 4                319.544                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan  MaturityDate_Last_year  \
# 0                                       0                    2010
# 1                                       0                    2009
# 2                                       0                    2014
# 3                                       0                    2010
# 4                                       0                    2010
#
#    MaturityDate_Last_month  MaturityDate_Last_day  LoanDate_year  \
# 0                        6                     25           2009
# 1                        7                     15           2009
# 2                        5                     13           2009
# 3                        9                     15           2009
# 4                        6                     25           2009
#
#    LoanDate_month  LoanDate_day  FirstPaymentDate_year  \
# 0               6            16                   2009
# 1               6            15                   2009
# 2               6            15                   2009
# 3               6            15                   2009
# 4               6            14                   2009
#
#    FirstPaymentDate_month  FirstPaymentDate_day  MaturityDate_Original_year  \
# 0                       7                    27                        2010
# 1                       7                    15                        2009
# 2                       7                    27                        2011
# 3                       7                    15                        2010
# 4                       7                    27                        2010
#
#    MaturityDate_Original_month  MaturityDate_Original_day  LastPaymentOn_year  \
# 0                            6                         25            2010.000
# 1                            7                         15            2009.000
# 2                            2                         25            2012.000
# 3                            9                         15            2010.000
# 4                            6                         25            2015.000
#
#    LastPaymentOn_month  LastPaymentOn_day
# 0                7.000              6.000
# 1                7.000              7.000
# 2               10.000              1.000
# 3                9.000             15.000
# 4                7.000             16.000

# %%
# NOW DROP THOSE DATE ORIGINAL COLUMNS

loan=loan.drop(['MaturityDate_Last','LoanDate','FirstPaymentDate','MaturityDate_Original','LastPaymentOn'],axis =1)
loan.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0                     0        0     115.041                  0
# 1                     0        0     140.606                  1
# 2                     0        0     319.558                  0
# 3                     0        0      57.520                  0
# 4                     0        0     319.558                  0
#
#     VerificationType LanguageCode  Age  Gender Country  AppliedAmount  Amount  \
# 0  Income unverified     Estonian   61  Female      EE        319.558 115.041
# 1  Income unverified     Estonian   48  Female      EE        191.735 140.606
# 2  Income unverified     Estonian   58  Female      EE        319.558 319.541
# 3  Income unverified     Estonian   23  Female      EE        127.823  57.520
# 4  Income unverified     Estonian   25  Female      EE        319.558 319.544
#
#    Interest  LoanDuration  MonthlyPayment    County          City  \
# 0    30.000            12             NaN     HARJU       TALLINN
# 1    25.000             1             NaN  IDA-VIRU  KOHTLA-JARVE
# 2    25.000            20             NaN     PÄRNU         PÄRNU
# 3    45.000            15             NaN     HARJU      PALDISKI
# 4    30.000            12             NaN     TARTU         TARTU
#
#             UseOfLoan             Education MaritalStatus EmploymentStatus  \
# 0               Other  Vocational education       Married   Fully employed
# 1               Other      Higher education      Divorced   Fully employed
# 2    Home improvement   Secondary education       Married   Fully employed
# 3  Loan consolidation       Basic education        Single              NaN
# 4             Vehicle   Secondary education    Cohabitant   Fully employed
#
#   EmploymentDurationCurrentEmployer            OccupationArea  \
# 0                        UpTo3Years      Retail and wholesale
# 1                    MoreThan5Years                 Education
# 2                        UpTo4Years  Hospitality and catering
# 3                        UpTo2Years                     Other
# 4                        UpTo2Years      Retail and wholesale
#
#   HomeOwnershipType  IncomeTotal  ExistingLiabilities  LiabilitiesTotal  \
# 0               NaN    10500.000                    0             0.000
# 1               NaN    10800.000                    0             0.000
# 2               NaN     7000.000                    0             0.000
# 3               NaN    11600.000                    0             0.000
# 4               NaN     6800.000                    0             0.000
#
#    RefinanceLiabilities  DebtToIncome  FreeCash  MonthlyPaymentDay Rating  \
# 0                     0         0.000     0.000                 25    NaN
# 1                     0         0.000     0.000                 15    NaN
# 2                     0         0.000     0.000                 25    NaN
# 3                     0         0.000     0.000                 15    NaN
# 4                     0         0.000     0.000                 25    NaN
#
#    Restructured CreditScoreEsMicroL  PrincipalPaymentsMade  \
# 0             1                 NaN                115.041
# 1             1                 NaN                140.606
# 2             0                 NaN                203.191
# 3             1                 NaN                 57.520
# 4             1                 NaN                319.544
#
#    InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                          20.422             0.000
# 1                           2.023             0.000
# 2                          59.763           116.350
# 3                          18.732             0.000
# 4                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan  MaturityDate_Last_year  \
# 0                                       0                    2010
# 1                                       0                    2009
# 2                                       0                    2014
# 3                                       0                    2010
# 4                                       0                    2010
#
#    MaturityDate_Last_month  MaturityDate_Last_day  LoanDate_year  \
# 0                        6                     25           2009
# 1                        7                     15           2009
# 2                        5                     13           2009
# 3                        9                     15           2009
# 4                        6                     25           2009
#
#    LoanDate_month  LoanDate_day  FirstPaymentDate_year  \
# 0               6            16                   2009
# 1               6            15                   2009
# 2               6            15                   2009
# 3               6            15                   2009
# 4               6            14                   2009
#
#    FirstPaymentDate_month  FirstPaymentDate_day  MaturityDate_Original_year  \
# 0                       7                    27                        2010
# 1                       7                    15                        2009
# 2                       7                    27                        2011
# 3                       7                    15                        2010
# 4                       7                    27                        2010
#
#    MaturityDate_Original_month  MaturityDate_Original_day  LastPaymentOn_year  \
# 0                            6                         25            2010.000
# 1                            7                         15            2009.000
# 2                            2                         25            2012.000
# 3                            9                         15            2010.000
# 4                            6                         25            2015.000
#
#    LastPaymentOn_month  LastPaymentOn_day
# 0                7.000              6.000
# 1                7.000              7.000
# 2               10.000              1.000
# 3                9.000             15.000
# 4                7.000             16.000

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134529 entries, 0 to 134528
# Data columns (total 56 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   BidsPortfolioManager                    134529 non-null  int64
#  1   BidsApi                                 134529 non-null  int64
#  2   BidsManual                              134529 non-null  float64
#  3   NewCreditCustomer                       134529 non-null  int64
#  4   VerificationType                        134484 non-null  object
#  5   LanguageCode                            134529 non-null  object
#  6   Age                                     134529 non-null  int64
#  7   Gender                                  134484 non-null  object
#  8   Country                                 134529 non-null  object
#  9   AppliedAmount                           134529 non-null  float64
#  10  Amount                                  134529 non-null  float64
#  11  Interest                                134529 non-null  float64
#  12  LoanDuration                            134529 non-null  int64
#  13  MonthlyPayment                          127844 non-null  float64
#  14  County                                  97689 non-null   object
#  15  City                                    124735 non-null  object
#  16  UseOfLoan                               134529 non-null  object
#  17  Education                               134484 non-null  object
#  18  MaritalStatus                           134484 non-null  object
#  19  EmploymentStatus                        134332 non-null  object
#  20  EmploymentDurationCurrentEmployer       133653 non-null  object
#  21  OccupationArea                          134443 non-null  object
#  22  HomeOwnershipType                       132877 non-null  object
#  23  IncomeTotal                             134529 non-null  float64
#  24  ExistingLiabilities                     134529 non-null  int64
#  25  LiabilitiesTotal                        134529 non-null  float64
#  26  RefinanceLiabilities                    134529 non-null  int64
#  27  DebtToIncome                            134484 non-null  float64
#  28  FreeCash                                134484 non-null  float64
#  29  MonthlyPaymentDay                       134529 non-null  int64
#  30  Rating                                  131799 non-null  object
#  31  Restructured                            134529 non-null  int64
#  32  CreditScoreEsMicroL                     104955 non-null  object
#  33  PrincipalPaymentsMade                   134529 non-null  float64
#  34  InterestAndPenaltyPaymentsMade          134529 non-null  float64
#  35  PrincipalBalance                        134529 non-null  float64
#  36  InterestAndPenaltyBalance               134529 non-null  float64
#  37  NoOfPreviousLoansBeforeLoan             134529 non-null  int64
#  38  AmountOfPreviousLoansBeforeLoan         134529 non-null  float64
#  39  PreviousRepaymentsBeforeLoan            91368 non-null   float64
#  40  PreviousEarlyRepaymentsCountBeforeLoan  134529 non-null  int64
#  41  MaturityDate_Last_year                  134529 non-null  int64
#  42  MaturityDate_Last_month                 134529 non-null  int64
#  43  MaturityDate_Last_day                   134529 non-null  int64
#  44  LoanDate_year                           134529 non-null  int64
#  45  LoanDate_month                          134529 non-null  int64
#  46  LoanDate_day                            134529 non-null  int64
#  47  FirstPaymentDate_year                   134529 non-null  int64
#  48  FirstPaymentDate_month                  134529 non-null  int64
#  49  FirstPaymentDate_day                    134529 non-null  int64
#  50  MaturityDate_Original_year              134529 non-null  int64
#  51  MaturityDate_Original_month             134529 non-null  int64
#  52  MaturityDate_Original_day               134529 non-null  int64
#  53  LastPaymentOn_year                      124998 non-null  float64
#  54  LastPaymentOn_month                     124998 non-null  float64
#  55  LastPaymentOn_day                       124998 non-null  float64
# dtypes: float64(18), int64(23), object(15)
# memory usage: 57.5+ MB

# %%
numerical_cols=[col for col in loan.columns if loan[col].dtype!=object]
categorical_cols=[col for col in loan.columns if loan[col].dtype==object]
print("No of Numerical features =",len(numerical_cols))
print("No of Categorical features =",len(categorical_cols))
# Out:
# No of Numerical features = 41
# No of Categorical features = 15

# %% [markdown]
# # Missing value treatment

# %%
numerical_columns=loan.select_dtypes(include=np.number)
numerical_columns.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  Age  \
# 0                     0        0     115.041                  0   61
# 1                     0        0     140.606                  1   48
# 2                     0        0     319.558                  0   58
# 3                     0        0      57.520                  0   23
# 4                     0        0     319.558                  0   25
#
#    AppliedAmount  Amount  Interest  LoanDuration  MonthlyPayment  IncomeTotal  \
# 0        319.558 115.041    30.000            12             NaN    10500.000
# 1        191.735 140.606    25.000             1             NaN    10800.000
# 2        319.558 319.541    25.000            20             NaN     7000.000
# 3        127.823  57.520    45.000            15             NaN    11600.000
# 4        319.558 319.544    30.000            12             NaN     6800.000
#
#    ExistingLiabilities  LiabilitiesTotal  RefinanceLiabilities  DebtToIncome  \
# 0                    0             0.000                     0         0.000
# 1                    0             0.000                     0         0.000
# 2                    0             0.000                     0         0.000
# 3                    0             0.000                     0         0.000
# 4                    0             0.000                     0         0.000
#
#    FreeCash  MonthlyPaymentDay  Restructured  PrincipalPaymentsMade  \
# 0     0.000                 25             1                115.041
# 1     0.000                 15             1                140.606
# 2     0.000                 25             0                203.191
# 3     0.000                 15             1                 57.520
# 4     0.000                 25             1                319.544
#
#    InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                          20.422             0.000
# 1                           2.023             0.000
# 2                          59.763           116.350
# 3                          18.732             0.000
# 4                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan  MaturityDate_Last_year  \
# 0                                       0                    2010
# 1                                       0                    2009
# 2                                       0                    2014
# 3                                       0                    2010
# 4                                       0                    2010
#
#    MaturityDate_Last_month  MaturityDate_Last_day  LoanDate_year  \
# 0                        6                     25           2009
# 1                        7                     15           2009
# 2                        5                     13           2009
# 3                        9                     15           2009
# 4                        6                     25           2009
#
#    LoanDate_month  LoanDate_day  FirstPaymentDate_year  \
# 0               6            16                   2009
# 1               6            15                   2009
# 2               6            15                   2009
# 3               6            15                   2009
# 4               6            14                   2009
#
#    FirstPaymentDate_month  FirstPaymentDate_day  MaturityDate_Original_year  \
# 0                       7                    27                        2010
# 1                       7                    15                        2009
# 2                       7                    27                        2011
# 3                       7                    15                        2010
# 4                       7                    27                        2010
#
#    MaturityDate_Original_month  MaturityDate_Original_day  LastPaymentOn_year  \
# 0                            6                         25            2010.000
# 1                            7                         15            2009.000
# 2                            2                         25            2012.000
# 3                            9                         15            2010.000
# 4                            6                         25            2015.000
#
#    LastPaymentOn_month  LastPaymentOn_day
# 0                7.000              6.000
# 1                7.000              7.000
# 2               10.000              1.000
# 3                9.000             15.000
# 4                7.000             16.000

# %%
categorical_columns=loan.select_dtypes('object')
categorical_columns.head()
categorical_columns.shape
# Out:
# (134529, 15)

# %%
def Numerical_Summary():
    for col in numerical_cols:
        print(col)
        print("No of Missing Values =",loan[col].isnull().sum())
        print("Skew =",loan[col].skew())
        print("Histogram")
        fig=px.histogram(data_frame=loan,x=col)
        fig.show()
        print("="*50)
        
def Categorical_Summary():
    for col in categorical_cols:
        print(col)
        print("No of Missin Values =",loan[col].isnull().sum())
        print(loan[col].value_counts())
        print("="*50)

# %%
# Numerical_Summary()

# %% [markdown]
# # Observations from above plots:-
# * Bids Columns have alot of zero values with skewed right distributions
# * Age has some values less then 10 which is not possible.
# * AppliedAmount,Amount are discrete and not continous and have skew of 1.5 and 1.6 .
# * Interest has 0 NAN's is highly skewed and alot of values are greather then 100.
# * Monthly Payments has 6685 NANs and is highly skewed right with some 0 values.
# * Alot of records has 0 IncomeTotal and high skew.
# * Debt to Income ratio is expressed as percentage, 2 observations have value greather then 100 which is not possible and has 45 NAN.
# * PlannedInterestTillDate is right skewed with 3000+ NANs.
# * Principal Overdueby Schedule is skewed right with NANs
# * CreditScoreEMini has 1 zero value.
# * 5 rows have Principal Amount less then 0.
# * Monthly payments,debt to income,free cash,Plnned Interest till date,Principal Overdue by Schedule,Previous Repayments Before Loan, Not Scheduled Payments has missing values.

# %%
loan_df = loan.copy()
loan_df =loan[loan['Age']>10]
loan_df=loan[loan['Age']>10]
loan_df=loan[loan['AppliedAmount']>0]
loan_df=loan[loan['DebtToIncome']<100]
loan_df=loan[loan['CreditScoreEsMicroL']!=0]
loan_df=loan[loan['PrincipalBalance']>=0]

# %%
loan_df = loan.copy()
loan_df =loan_df[loan_df['Age']>10]
loan_df=loan_df[loan_df['Age']>10]
loan_df=loan_df[loan_df['AppliedAmount']>0]
loan_df=loan_df[loan_df['DebtToIncome']<100]
loan_df=loan_df[loan_df['CreditScoreEsMicroL']!=0]
loan_df=loan_df[loan_df['PrincipalBalance']>=0]

# %%
print(loan.shape)
print(loan_df.shape)
# Out:
# (134529, 56)
# (134469, 56)

# %%
loan_df.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0                     0        0     115.041                  0
# 1                     0        0     140.606                  1
# 2                     0        0     319.558                  0
# 3                     0        0      57.520                  0
# 4                     0        0     319.558                  0
#
#     VerificationType LanguageCode  Age  Gender Country  AppliedAmount  Amount  \
# 0  Income unverified     Estonian   61  Female      EE        319.558 115.041
# 1  Income unverified     Estonian   48  Female      EE        191.735 140.606
# 2  Income unverified     Estonian   58  Female      EE        319.558 319.541
# 3  Income unverified     Estonian   23  Female      EE        127.823  57.520
# 4  Income unverified     Estonian   25  Female      EE        319.558 319.544
#
#    Interest  LoanDuration  MonthlyPayment    County          City  \
# 0    30.000            12             NaN     HARJU       TALLINN
# 1    25.000             1             NaN  IDA-VIRU  KOHTLA-JARVE
# 2    25.000            20             NaN     PÄRNU         PÄRNU
# 3    45.000            15             NaN     HARJU      PALDISKI
# 4    30.000            12             NaN     TARTU         TARTU
#
#             UseOfLoan             Education MaritalStatus EmploymentStatus  \
# 0               Other  Vocational education       Married   Fully employed
# 1               Other      Higher education      Divorced   Fully employed
# 2    Home improvement   Secondary education       Married   Fully employed
# 3  Loan consolidation       Basic education        Single              NaN
# 4             Vehicle   Secondary education    Cohabitant   Fully employed
#
#   EmploymentDurationCurrentEmployer            OccupationArea  \
# 0                        UpTo3Years      Retail and wholesale
# 1                    MoreThan5Years                 Education
# 2                        UpTo4Years  Hospitality and catering
# 3                        UpTo2Years                     Other
# 4                        UpTo2Years      Retail and wholesale
#
#   HomeOwnershipType  IncomeTotal  ExistingLiabilities  LiabilitiesTotal  \
# 0               NaN    10500.000                    0             0.000
# 1               NaN    10800.000                    0             0.000
# 2               NaN     7000.000                    0             0.000
# 3               NaN    11600.000                    0             0.000
# 4               NaN     6800.000                    0             0.000
#
#    RefinanceLiabilities  DebtToIncome  FreeCash  MonthlyPaymentDay Rating  \
# 0                     0         0.000     0.000                 25    NaN
# 1                     0         0.000     0.000                 15    NaN
# 2                     0         0.000     0.000                 25    NaN
# 3                     0         0.000     0.000                 15    NaN
# 4                     0         0.000     0.000                 25    NaN
#
#    Restructured CreditScoreEsMicroL  PrincipalPaymentsMade  \
# 0             1                 NaN                115.041
# 1             1                 NaN                140.606
# 2             0                 NaN                203.191
# 3             1                 NaN                 57.520
# 4             1                 NaN                319.544
#
#    InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                          20.422             0.000
# 1                           2.023             0.000
# 2                          59.763           116.350
# 3                          18.732             0.000
# 4                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan  MaturityDate_Last_year  \
# 0                                       0                    2010
# 1                                       0                    2009
# 2                                       0                    2014
# 3                                       0                    2010
# 4                                       0                    2010
#
#    MaturityDate_Last_month  MaturityDate_Last_day  LoanDate_year  \
# 0                        6                     25           2009
# 1                        7                     15           2009
# 2                        5                     13           2009
# 3                        9                     15           2009
# 4                        6                     25           2009
#
#    LoanDate_month  LoanDate_day  FirstPaymentDate_year  \
# 0               6            16                   2009
# 1               6            15                   2009
# 2               6            15                   2009
# 3               6            15                   2009
# 4               6            14                   2009
#
#    FirstPaymentDate_month  FirstPaymentDate_day  MaturityDate_Original_year  \
# 0                       7                    27                        2010
# 1                       7                    15                        2009
# 2                       7                    27                        2011
# 3                       7                    15                        2010
# 4                       7                    27                        2010
#
#    MaturityDate_Original_month  MaturityDate_Original_day  LastPaymentOn_year  \
# 0                            6                         25            2010.000
# 1                            7                         15            2009.000
# 2                            2                         25            2012.000
# 3                            9                         15            2010.000
# 4                            6                         25            2015.000
#
#    LastPaymentOn_month  LastPaymentOn_day
# 0                7.000              6.000
# 1                7.000              7.000
# 2               10.000              1.000
# 3                9.000             15.000
# 4                7.000             16.000

# %%
Categorical_Summary()
# Out:
# VerificationType
# No of Missin Values = 45
# Income and expenses verified    74572
# Income unverified               50476
# Income verified                  9428
# Not set                             8
# Name: VerificationType, dtype: int64
# ==================================================
# LanguageCode
# No of Missin Values = 0
# Estonian     64299
# Finnish      32155
# Spanish      24103
# Russian      12694
# English        967
# Slovakian      295
# other           11
# German           5
# Name: LanguageCode, dtype: int64
# ==================================================
# Gender
# No of Missin Values = 45
# Male         85650
# Female       38213
# Undefined    10621
# Name: Gender, dtype: int64
# ==================================================
# Country
# No of Missin Values = 0
# EE    77335
# FI    32650
# ES    24248
# SK      296
# Name: Country, dtype: int64
# ==================================================
# County
# No of Missin Values = 36840
# Harju maakond         22224
# HARJU                  8108
# Tartu maakond          6181
# UUSIMAA                6076
# Ida-Viru maakond       4197
#                       ...
# KILVAKKALA                1
# IRUN GIPUZKOA             1
# PÄRNUMAA   PÄRNU          1
# ETELÄ - POHJANMAA         1
# POHJOIS-POHJOINMAA        1
# Name: County, Length: 1010, dtype: int64
# ==================================================
# City
# No of Missin Values = 9794
# Tallinn                       15604
# TALLINN                        6146
# Tartu linn                     3326
# HELSINKI                       3294
# Pärnu linn                     1986
#                               ...
# KOSE VALD, ARDU                   1
# KALAMAJA                          1
# LLERENA                           1
# SALME VALD, TEHUMARDI KÜLA        1
# VEĽKÉ DRŽKOVCE                    1
# Name: City, Length: 7733, dtype: int64
# ==================================================
# UseOfLoan
# No of Missin Values = 0
# Not set category                   97946
# Other                               9698
# Home improvement                    9191
# Loan consolidation                  6914
# Vehicle                             3150
# Business                            1950
# Travel                              1787
# Health                              1519
# Education                           1366
# Real estate                          955
# Purchase of machinery equipment       21
# Other business                        17
# Accounts receivable financing          6
# Working capital financing              5
# Acquisition of stocks                  2
# Acquisition of real estate             1
# Construction finance                   1
# Name: UseOfLoan, dtype: int64
# ==================================================
# Education
# No of Missin Values = 45
# Secondary education     51330
# Higher education        35398
# Vocational education    29260
# Primary                 12057
# Basic education          6427
# Not_present                12
# Name: Education, dtype: int64
# ==================================================
# MaritalStatus
# No of Missin Values = 45
# Not_specified    97954
# Single           12400
# Married          10752
# Cohabitant        9400
# Divorced          3377
# Widow              601
# Name: MaritalStatus, dtype: int64
# ==================================================
# EmploymentStatus
# No of Missin Values = 197
# Not_specified         97978
# Fully employed        30060
# Entrepreneur           2007
# Retiree                1800
# Self-employed          1303
# Partially employed     1184
# Name: EmploymentStatus, dtype: int64
# ==================================================
# EmploymentDurationCurrentEmployer
# No of Missin Values = 876
# MoreThan5Years    52089
# UpTo5Years        28411
# UpTo1Year         24187
# Retiree            7552
# UpTo2Years         6498
# UpTo3Years         5435
# Other              5048
# UpTo4Years         3684
# TrialPeriod         749
# Name: EmploymentDurationCurrentEmployer, dtype: int64
# ==================================================
# OccupationArea
# No of Missin Values = 86
# Not_specified                       98008
# Other                                8421
# Retail and wholesale                 3587
# Construction                         3312
# Processing                           3198
# Transport and warehousing            2462
# Healthcare and social help           2424
# Hospitality and catering             2262
# Info and telecom                     1933
# Civil service & military             1684
# Education                            1430
# Finance and insurance                1148
# Agriculture,forestry and fishing     1000
# Administrative                        843
# Art and entertainment                 619
# Energy                                587
# Research                              564
# Real-estate                           477
# Utilities                             362
# Mining                                122
# Name: OccupationArea, dtype: int64
# ==================================================
# HomeOwnershipType
# No of Missin Values = 1652
# Owner                             47334
# Tenant, pre-furnished property    29579
# Living with parents               20780
# Mortgage                          15457
# Other                              7956
# Tenant, unfurnished property       4582
# Joint ownership                    3337
# Joint tenant                       1618
# Council house                      1442
# Owner with encumbrance              743
# Homeless                             46
# Not_specified                         3
# Name: HomeOwnershipType, dtype: int64
# ==================================================
# Rating
# No of Missin Values = 2730
# E     24461
# F     24161
# D     21558
# C     19845
# B     14636
# HR    14122
# A      6905
# AA     6111
# Name: Rating, dtype: int64
# ==================================================
# CreditScoreEsMicroL
# No of Missin Values = 29574
# M      92439
# M1      4321
# M5      2432
# M2      1723
# M3      1644
# M4      1540
# M6       560
# M8       102
# M9        70
# M7        69
# M10       55
# Name: CreditScoreEsMicroL, dtype: int64
# ==================================================

# %% [markdown]
# # Observations
# City,Education,Martial Status,CreditScore,EsMicroEl,Rating,HomeOwnershipType,Occupation Area,EmploymentDuration,Country, VerificationType have missing values.

# %% [markdown]
# # FILL NULL VALUES

# %%
# numerical_columns.isnull().sum()
numerical_columns=numerical_columns.fillna(numerical_columns.mean().iloc[0])
numerical_columns.isnull().sum()
numerical_columns.head()
# Out:
#    BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  Age  \
# 0                     0        0     115.041                  0   61
# 1                     0        0     140.606                  1   48
# 2                     0        0     319.558                  0   58
# 3                     0        0      57.520                  0   23
# 4                     0        0     319.558                  0   25
#
#    AppliedAmount  Amount  Interest  LoanDuration  MonthlyPayment  IncomeTotal  \
# 0        319.558 115.041    30.000            12         966.453    10500.000
# 1        191.735 140.606    25.000             1         966.453    10800.000
# 2        319.558 319.541    25.000            20         966.453     7000.000
# 3        127.823  57.520    45.000            15         966.453    11600.000
# 4        319.558 319.544    30.000            12         966.453     6800.000
#
#    ExistingLiabilities  LiabilitiesTotal  RefinanceLiabilities  DebtToIncome  \
# 0                    0             0.000                     0         0.000
# 1                    0             0.000                     0         0.000
# 2                    0             0.000                     0         0.000
# 3                    0             0.000                     0         0.000
# 4                    0             0.000                     0         0.000
#
#    FreeCash  MonthlyPaymentDay  Restructured  PrincipalPaymentsMade  \
# 0     0.000                 25             1                115.041
# 1     0.000                 15             1                140.606
# 2     0.000                 25             0                203.191
# 3     0.000                 15             1                 57.520
# 4     0.000                 25             1                319.544
#
#    InterestAndPenaltyPaymentsMade  PrincipalBalance  \
# 0                          20.422             0.000
# 1                           2.023             0.000
# 2                          59.763           116.350
# 3                          18.732             0.000
# 4                         220.420             0.000
#
#    InterestAndPenaltyBalance  NoOfPreviousLoansBeforeLoan  \
# 0                      0.000                            1
# 1                      0.000                            2
# 2                    414.070                            0
# 3                      0.000                            1
# 4                      0.000                            1
#
#    AmountOfPreviousLoansBeforeLoan  PreviousRepaymentsBeforeLoan  \
# 0                           83.085                         0.000
# 1                          255.647                       258.626
# 2                            0.000                         0.000
# 3                          134.214                         0.000
# 4                          146.997                         0.000
#
#    PreviousEarlyRepaymentsCountBeforeLoan  MaturityDate_Last_year  \
# 0                                       0                    2010
# 1                                       0                    2009
# 2                                       0                    2014
# 3                                       0                    2010
# 4                                       0                    2010
#
#    MaturityDate_Last_month  MaturityDate_Last_day  LoanDate_year  \
# 0                        6                     25           2009
# 1                        7                     15           2009
# 2                        5                     13           2009
# 3                        9                     15           2009
# 4                        6                     25           2009
#
#    LoanDate_month  LoanDate_day  FirstPaymentDate_year  \
# 0               6            16                   2009
# 1               6            15                   2009
# 2               6            15                   2009
# 3               6            15                   2009
# 4               6            14                   2009
#
#    FirstPaymentDate_month  FirstPaymentDate_day  MaturityDate_Original_year  \
# 0                       7                    27                        2010
# 1                       7                    15                        2009
# 2                       7                    27                        2011
# 3                       7                    15                        2010
# 4                       7                    27                        2010
#
#    MaturityDate_Original_month  MaturityDate_Original_day  LastPaymentOn_year  \
# 0                            6                         25            2010.000
# 1                            7                         15            2009.000
# 2                            2                         25            2012.000
# 3                            9                         15            2010.000
# 4                            6                         25            2015.000
#
#    LastPaymentOn_month  LastPaymentOn_day
# 0                7.000              6.000
# 1                7.000              7.000
# 2               10.000              1.000
# 3                9.000             15.000
# 4                7.000             16.000

# %%
# numerical_columns.isnull().sum()
categorical_columns=categorical_columns.fillna(categorical_columns.mode().iloc[0])
categorical_columns.isnull().sum()
categorical_columns.head()
# Out:
#     VerificationType LanguageCode  Gender Country    County          City  \
# 0  Income unverified     Estonian  Female      EE     HARJU       TALLINN
# 1  Income unverified     Estonian  Female      EE  IDA-VIRU  KOHTLA-JARVE
# 2  Income unverified     Estonian  Female      EE     PÄRNU         PÄRNU
# 3  Income unverified     Estonian  Female      EE     HARJU      PALDISKI
# 4  Income unverified     Estonian  Female      EE     TARTU         TARTU
#
#             UseOfLoan             Education MaritalStatus EmploymentStatus  \
# 0               Other  Vocational education       Married   Fully employed
# 1               Other      Higher education      Divorced   Fully employed
# 2    Home improvement   Secondary education       Married   Fully employed
# 3  Loan consolidation       Basic education        Single    Not_specified
# 4             Vehicle   Secondary education    Cohabitant   Fully employed
#
#   EmploymentDurationCurrentEmployer            OccupationArea  \
# 0                        UpTo3Years      Retail and wholesale
# 1                    MoreThan5Years                 Education
# 2                        UpTo4Years  Hospitality and catering
# 3                        UpTo2Years                     Other
# 4                        UpTo2Years      Retail and wholesale
#
#   HomeOwnershipType Rating CreditScoreEsMicroL
# 0             Owner      E                   M
# 1             Owner      E                   M
# 2             Owner      E                   M
# 3             Owner      E                   M
# 4             Owner      E                   M

# %%
plt.figure(figsize=(25,25))
sns.heatmap(loan_df[numerical_cols].corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observations
# * As Applied Ammount,Ammount increases monthlypayments,PrincipalBalance increase.
# * As Loan Duration increases No of Rescheduled Payments also increases.
# * Income increases Applied Ammount and Ammount increase and because of that Principal Balance increase e.g A->B,B->C therefore A->C
# * No of Previous Loans increase AmmountofPreviousLoan also increase.
# * As Unpaid Interest increases Principal that is overdue also increases.
# * So there is slight Multicollinearity.

# %%
pd.crosstab(t_v , loan['UseOfLoan'])
# Out:
# UseOfLoan  Accounts receivable financing  Acquisition of real estate  \
# Status
# Current                                0                           0
# Late                                   0                           0
# Repaid                                 6                           1
#
# UseOfLoan  Acquisition of stocks  Business  Construction finance  Education  \
# Status
# Current                        0       207                     0        107
# Late                           0       813                     0        585
# Repaid                         2       930                     1        674
#
# UseOfLoan  Health  Home improvement  Loan consolidation  Not set category  \
# Status
# Current       152              1089                 495             53769
# Late          649              4007                2665             30432
# Repaid        718              4095                3754             13745
#
# UseOfLoan  Other  Other business  Purchase of machinery equipment  \
# Status
# Current      772               0                                0
# Late        4371               0                                0
# Repaid      4555              17                               21
#
# UseOfLoan  Real estate  Travel  Vehicle  Working capital financing
# Status
# Current            112     166      266                          0
# Late               366     741     1143                          0
# Repaid             477     880     1741                          5

# %% [markdown]
# # ENCODING

# %% [markdown]
# # <center><span style="color:#A8AD10;"> Preprocessing for Categorical data </span></center>
# <center>We will use Z-Score for normalization</center>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
categorical_columns.shape
# Out:
# (134529, 15)

# %%
encode_cat = categorical_columns.apply(LabelEncoder().fit_transform)
encode_cat
# Out:
#         VerificationType  LanguageCode  Gender  Country  County  City  \
# 0                      1             1       0        0     234  6398
# 1                      1             1       0        0     283  2709
# 2                      1             1       0        0     732  5188
# 3                      1             1       0        0     234  4689
# 4                      1             1       0        0     856  6446
# ...                  ...           ...     ...      ...     ...   ...
# 134524                 2             2       1        2     724  3258
# 134525                 2             2       1        2     665  2231
# 134526                 1             2       1        2     934  5981
# 134527                 0             1       0        0     916  6955
# 134528                 0             1       0        0     234  6398
#
#         UseOfLoan  Education  MaritalStatus  EmploymentStatus  \
# 0              10          5              2                 1
# 1              10          1              1                 1
# 2               7          4              2                 1
# 3               8          0              4                 2
# 4              15          4              0                 1
# ...           ...        ...            ...               ...
# 134524          8          5              4                 1
# 134525          7          5              4                 1
# 134526          8          5              2                 0
# 134527         10          1              2                 1
# 134528          8          4              4                 1
#
#         EmploymentDurationCurrentEmployer  OccupationArea  HomeOwnershipType  \
# 0                                       6              17                  8
# 1                                       0               5                  8
# 2                                       7               9                  8
# 3                                       5              13                  8
# 4                                       5              17                  8
# ...                                   ...             ...                ...
# 134524                                  0              13                  0
# 134525                                  0              18                  8
# 134526                                  0               4                  8
# 134527                                  0               8                 11
# 134528                                  6               1                  4
#
#         Rating  CreditScoreEsMicroL
# 0            5                    0
# 1            5                    0
# 2            5                    0
# 3            5                    0
# 4            5                    0
# ...        ...                  ...
# 134524       5                    0
# 134525       2                    0
# 134526       4                    0
# 134527       2                    0
# 134528       4                    0
#
# [134529 rows x 15 columns]

# %%
df_main_dummy = pd.concat([numerical_columns,encode_cat], axis=1)

# display first five observations
df_main_dummy.head()
df_main_dummy.shape
# Out:
# (134529, 56)

# %% [markdown]
# # NOW GO FOR BASE MODEL
# - because if we cant run a model , how can we decide that our model needs feature engineering

# %%
# set of independent variables
# create a copy of 'df_compensation_dummy' and store in the dataframe 'X_full'
X_full = df_main_dummy.copy()
# create a copy of 'df_target' and store in the dataframe 'y_full'
y_full = t_v.copy()
# to estimate the regression coefficient, a constant term of '1' needs to be added as a separate column
# 'sm.add_constant' adds the intercept to the model
X_full = sm.add_constant(X_full)

# split data into train subset and test subset
# set 'random_state' to generate the same dataset each time you run the code 
# 'test_size' returns the proportion of data to be included in the testing set
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, random_state=1, test_size = 0.3)

# checking the dimensions of the train & test subset
# print dimension of train set
print('X_train_full', X_train_full.shape)
print('y_train_full', y_train_full.shape)

# print dimension of test set
print('X_test_full', X_test_full.shape)
print('y_test_full', y_test_full.shape)

print('X_clms: ',X_full.columns)# dependent variable
# Out:
# X_train_full (94170, 57)
# y_train_full (94170,)
# X_test_full (40359, 57)
# y_test_full (40359,)
# X_clms:  Index(['const', 'BidsPortfolioManager', 'BidsApi', 'BidsManual',
#        'NewCreditCustomer', 'Age', 'AppliedAmount', 'Amount', 'Interest',
#        'LoanDuration', 'MonthlyPayment', 'IncomeTotal', 'ExistingLiabilities',
#        'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash',
#        'MonthlyPaymentDay', 'Restructured', 'PrincipalPaymentsMade',
#        'InterestAndPenaltyPaymentsMade', 'PrincipalBalance',
#        'InterestAndPenaltyBalance', 'NoOfPreviousLoansBeforeLoan',
#        'AmountOfPreviousLoansBeforeLoan', 'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan', 'MaturityDate_Last_year',
#        'MaturityDate_Last_month', 'MaturityDate_Last_day', 'LoanDate_year',
#        'LoanDate_month', 'LoanDate_day', 'FirstPaymentDate_year',
#        'FirstPaymentDate_month', 'FirstPaymentDate_day',
#        'MaturityDate_Original_year', 'MaturityDate_Original_month',
#        'MaturityDate_Original_day', 'LastPaymentOn_year',
#        'LastPaymentOn_month', 'LastPaymentOn_day', 'VerificationType',
#        'LanguageCode', 'Gender', 'Country', 'County', 'City', 'UseOfLoan',
#        'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'Rating', 'CreditScoreEsMicroL'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
base_model = LR.fit(X_train_full,y_train_full)

# %%
predict = base_model.predict(X_train_full)
predict
# Out:
# array(['Current', 'Current', 'Current', ..., 'Current', 'Repaid',
#        'Current'], dtype=object)

# %%
predictx = base_model.predict(X_test_full)
predictx
# Out:
# array(['Current', 'Late', 'Late', ..., 'Repaid', 'Late', 'Current'],
#       dtype=object)

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_train_full,predict)
# Out:
# array([[38990,   672,   365],
#        [ 4597, 27333,   160],
#        [   29,    24, 22000]], dtype=int64)

# %%
sns.countplot(x=predict)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
from sklearn.metrics import classification_report

# %%
#for train data
print(classification_report(y_train_full,predict))
# Out:
#               precision    recall  f1-score   support
#
#      Current       0.89      0.97      0.93     40027
#         Late       0.98      0.85      0.91     32090
#       Repaid       0.98      1.00      0.99     22053
#
#     accuracy                           0.94     94170
#    macro avg       0.95      0.94      0.94     94170
# weighted avg       0.94      0.94      0.94     94170

# %%
#for test data
from sklearn.metrics import classification_report 
print(classification_report(y_test_full,predictx))
# Out:
#               precision    recall  f1-score   support
#
#      Current       0.90      0.98      0.94     17108
#         Late       0.98      0.86      0.91     13682
#       Repaid       0.98      1.00      0.99      9569
#
#     accuracy                           0.94     40359
#    macro avg       0.95      0.94      0.95     40359
# weighted avg       0.94      0.94      0.94     40359

# %%
print('Accuracy of logistic regression classifier on train set: {:.2f}'.format(LR.score(X_train_full, y_train_full)))
# Out:
# Accuracy of logistic regression classifier on train set: 0.94

# %%
    print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(LR.score(X_test_full, y_test_full)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.94

# %%
from sklearn.metrics import accuracy_score

print ("Accuracy : ", accuracy_score(y_test_full,predictx))
# Out:
# Accuracy :  0.9410540399910801

# %%
comparison = pd.DataFrame({'Predicted Values':predictx,'Actual Values':y_test_full})
comparison
# Out:
#        Predicted Values Actual Values
# 30069           Current          Late
# 87389              Late          Late
# 13853              Late          Late
# 93997            Repaid        Repaid
# 89449           Current       Current
# ...                 ...           ...
# 107406             Late          Late
# 95761           Current       Current
# 62273            Repaid        Repaid
# 70989              Late          Late
# 105421          Current       Current
#
# [40359 rows x 2 columns]

# %% [markdown]
# ### **Confusion matrix**

# %%
c_matrix = confusion_matrix(y_test_full, predictx)  
print ("Confusion matrix : \n", c_matrix)
# Out:
# Confusion matrix :
#  [[16707   231   170]
#  [ 1900 11721    61]
#  [    5    12  9552]]

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(LR,X_test_full,y_test_full)

# %% [markdown]
# # RANDOM FOREST

# %%
# set of independent variables
# create a copy of 'df_compensation_dummy' and store in the dataframe 'X_full'
X_full = df_main_dummy.copy()
# create a copy of 'df_target' and store in the dataframe 'y_full'
y_full = t_v.copy()
# to estimate the regression coefficient, a constant term of '1' needs to be added as a separate column
# 'sm.add_constant' adds the intercept to the model
X_full = sm.add_constant(X_full)

# split data into train subset and test subset
# set 'random_state' to generate the same dataset each time you run the code 
# 'test_size' returns the proportion of data to be included in the testing set
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, random_state=1, test_size = 0.3)

# checking the dimensions of the train & test subset
# print dimension of train set
print('X_train_full', X_train_full.shape)
print('y_train_full', y_train_full.shape)

# print dimension of test set
print('X_test_full', X_test_full.shape)
print('y_test_full', y_test_full.shape)

print('X_clms: ',X_full.columns)# dependent variable
# Out:
# X_train_full (94170, 57)
# y_train_full (94170,)
# X_test_full (40359, 57)
# y_test_full (40359,)
# X_clms:  Index(['const', 'BidsPortfolioManager', 'BidsApi', 'BidsManual',
#        'NewCreditCustomer', 'Age', 'AppliedAmount', 'Amount', 'Interest',
#        'LoanDuration', 'MonthlyPayment', 'IncomeTotal', 'ExistingLiabilities',
#        'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash',
#        'MonthlyPaymentDay', 'Restructured', 'PrincipalPaymentsMade',
#        'InterestAndPenaltyPaymentsMade', 'PrincipalBalance',
#        'InterestAndPenaltyBalance', 'NoOfPreviousLoansBeforeLoan',
#        'AmountOfPreviousLoansBeforeLoan', 'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan', 'MaturityDate_Last_year',
#        'MaturityDate_Last_month', 'MaturityDate_Last_day', 'LoanDate_year',
#        'LoanDate_month', 'LoanDate_day', 'FirstPaymentDate_year',
#        'FirstPaymentDate_month', 'FirstPaymentDate_day',
#        'MaturityDate_Original_year', 'MaturityDate_Original_month',
#        'MaturityDate_Original_day', 'LastPaymentOn_year',
#        'LastPaymentOn_month', 'LastPaymentOn_day', 'VerificationType',
#        'LanguageCode', 'Gender', 'Country', 'County', 'City', 'UseOfLoan',
#        'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'Rating', 'CreditScoreEsMicroL'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classification=RandomForestClassifier(n_estimators=10,random_state=10)

# %%
rf_model=rf_classification.fit(X_train_full,y_train_full)

# %%
rf_model1=rf_classification.fit(X_test_full,y_test_full)

# %%
from sklearn.metrics import classification_report

# %%
predict_rftrain=rf_model.predict(X_train_full)
predict_rftest=rf_model1.predict(X_test_full)

# %%
print(classification_report(y_train_full,predict_rftrain))
# Out:
#               precision    recall  f1-score   support
#
#      Current       0.99      0.97      0.98     40027
#         Late       0.96      0.99      0.97     32090
#       Repaid       1.00      1.00      1.00     22053
#
#     accuracy                           0.98     94170
#    macro avg       0.98      0.99      0.98     94170
# weighted avg       0.98      0.98      0.98     94170

# %%
print(classification_report(y_test_full,predict_rftest))
# Out:
#               precision    recall  f1-score   support
#
#      Current       1.00      1.00      1.00     17108
#         Late       1.00      1.00      1.00     13682
#       Repaid       1.00      1.00      1.00      9569
#
#     accuracy                           1.00     40359
#    macro avg       1.00      1.00      1.00     40359
# weighted avg       1.00      1.00      1.00     40359

# %%
tuned_params=[{'criterion':['entopy','gini'],'max_depth':[10,20,30],
               'max_features':['log2','sqrt'],'min_samples_split':[2,5,8,11],
               'min_samples_leaf':[1,5,9],'n_estimators':[10,30,50,70]}]

# %%
rfc=RandomForestClassifier(random_state=10)

# %%
from sklearn.model_selection import GridSearchCV
rf_grid=GridSearchCV(estimator=rfc,param_grid=tuned_params,cv=5)

# %%
tree_grid_model = rf_grid.fit(X_train_full,y_train_full)

# %%
print(tree_grid_model.best_params_)

# %%
dt3=RandomForestClassifier(criterion='gini', max_depth= 10, max_features='log2', 
                          min_samples_leaf= 5, min_samples_split= 11,n_estimators=30)

# %%
rf_model_new=rf_classification.fit(X_train_full,y_train_full)

# %%
predict1_train=rf_model_new.predict(X_train_full)
predict1_train.shape

# %%
predict1_test=rf_model_new.predict(X_test_full)
predict1_test.shape

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train_full,predict1_train))

# %%
print(classification_report(y_test_full,predict1_test))
# some column give more importance that time accurancy change

# %%
from sklearn.model_selection import RandomizedSearchCV

def Linear_SVC_Rand(x, y, param, kfold, n):
    param_grid = {'C':param}
    k = StratifiedKFold(n_splits=kfold, shuffle=True, random_state=0)
    randsearch = RandomizedSearchCV(LinearSVC(), param_distributions=param_grid, cv=k, n_jobs=4,
                                    verbose=1, n_iter=n)

    return randsearch.fit(x, y)

start = timer()
param = [i/1000 for i in range(1,1000)]
param1 = [i for i in range(1,101)]
param.extend(param1)

#progress = progressbar.bar.ProgressBar()
clf = Linear_SVC_Rand(x=X_train, y=y_train, param=param, kfold=3, n=100)

print('LinearSVC:')
print('Best cv accuracy: {}' .format(clf.best_score_))
print('Test set score:   {}' .format(clf.score(X_test, y_test)))
print('Best parameters:  {}' .format(clf.best_params_))
print()

duration = timer() - start
print('time to run: {}' .format(duration))

# %%
import os
# open file
file = open('./NEW BONDORA FILE .ipynb')

# get the cursor positioned at end
file.seek(0, os.SEEK_END)

# get the current position of cursor
# this will be equivalent to size of file
print("Size of file is :", file.tell(), "bytes")
# Out:
# Size of file is : 75624662 bytes
